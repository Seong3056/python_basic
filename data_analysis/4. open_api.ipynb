# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # 영화진흥위원회 api
#
# - 예시 url

# %%
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20120101"

res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
data = res.json()

# %%
data
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20120101~20120101',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112207',
#     'movieNm': '미션임파서블:고스트프로토콜',
#     'openDt': '2011-12-15',
#     'salesAmt': '2776060500',
#     'salesShare': '36.3',
#     'salesInten': '-415699000',
#     'salesChange': '-13',
#     'salesAcc': '40541108500',
#     'audiCnt': '353274',
#     'audiInten': '-60106',
#     'audiChange': '-14.5',
#     'audiAcc': '5328435',
#     'scrnCnt': '697',
#     'showCnt': '3223'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20110295',
#     'movieNm': '마이 웨이',
#     'openDt': '2011-12-21',
#     'salesAmt': '1189058500',
#     'salesShare': '15.6',
#     'salesInten': '-105894500',
#     'salesChange': '-8.2',
#     'salesAcc': '13002897500',
#     'audiCnt': '153501',
# ...

# %% [markdown]
# - 개인 키

# %%
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=dd090a87e117bd0dbbbcfe3c133da120&targetDt=20240122&itemPerPage=5"

res = requests.get(url)

# %%
data = res.json()

# %%
data
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20240122~20240122',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235253',
#     'movieNm': '외계+인 2부',
#     'openDt': '2024-01-10',
#     'salesAmt': '274438190',
#     'salesShare': '30.9',
#     'salesInten': '-824392230',
#     'salesChange': '-75',
#     'salesAcc': '10884908623',
#     'audiCnt': '28746',
#     'audiInten': '-82725',
#     'audiChange': '-74.2',
#     'audiAcc': '1121624',
#     'scrnCnt': '1223',
#     'showCnt': '4160'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235834',
#     'movieNm': '위시',
#     'openDt': '2024-01-03',
#     'salesAmt': '131548445',
#     'salesShare': '14.8',
#     'salesInten': '-367576762',
#     'salesChange': '-73.6',
#     'salesAcc': '11765205471',
#     'audiCnt': '14157',
#     'audiInten': '-37025',
# ...

# %%
for i in data["boxOfficeResult"]["dailyBoxOfficeList"]:
    print(i["movieNm"])
# Out:
# 외계+인 2부
# 위시
# 서울의 봄
# 노량: 죽음의 바다
# 인투 더 월드

# %%
key = "dd090a87e117bd0dbbbcfe3c133da120"
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json"

params = {"key" : key,
          "targetDt" : "20240121",
          "repNationCd" : "F"
          }
res = requests.get(url, params = params)
res.url
# Out:
# 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=dd090a87e117bd0dbbbcfe3c133da120&targetDt=20240121&repNationCd=F'

# %%
res.json()
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20240121~20240121',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235834',
#     'movieNm': '위시',
#     'openDt': '2024-01-03',
#     'salesAmt': '499125207',
#     'salesShare': '41.1',
#     'salesInten': '-55690349',
#     'salesChange': '-10',
#     'salesAcc': '11633657026',
#     'audiCnt': '51182',
#     'audiInten': '-6056',
#     'audiChange': '-10.6',
#     'audiAcc': '1214451',
#     'scrnCnt': '949',
#     'showCnt': '2879'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235583',
#     'movieNm': '인투 더 월드',
#     'openDt': '2024-01-10',
#     'salesAmt': '269282778',
#     'salesShare': '22.2',
#     'salesInten': '-9014610',
#     'salesChange': '-3.2',
#     'salesAcc': '2257977172',
#     'audiCnt': '28666',
#     'audiInten': '-890',
# ...

# %% [markdown]
# # 네이버 검색 api

# %%
url = "https://openapi.naver.com/v1/search/blog.json"

word = "신촌 맛집"

params = {"query" : word}

headers = {"X-Naver-Client-Id" : "unSNY2EflKVo__PP4GFq",
           "X-Naver-Client-Secret" : "w_R7X7PZmj"}

res = requests.get(url, params = params, headers = headers)

# %%
res.url
# Out:
# 'https://openapi.naver.com/v1/search/blog.json?query=%EC%8B%A0%EC%B4%8C+%EB%A7%9B%EC%A7%91'

# %%
res.json()
# Out:
# {'lastBuildDate': 'Tue, 23 Jan 2024 09:49:15 +0900',
#  'total': 212719,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>신촌 맛집</b> | 신촌 스테이크, 이빠네마 그릴',
#    'link': 'https://blog.naver.com/happygirlbg/223284079874',
#    'description': '딱 그 맛, 그냥 헤어지기 아쉬워 근처 카페에 가서 차 한 잔 하며 마무리해줬네요〰️ 연말 <b>신촌 맛집</b>이나 신촌 스테이크 가게 찾으시는 분들에게 조금이나마 도움되길 바라며 글 마무리할게요, 편안한 하루... ',
#    'bloggername': '크고 넓게 하늘을 날 고 싶 다.',
#    'bloggerlink': 'blog.naver.com/happygirlbg',
#    'postdate': '20231205'},
#   {'title': '<b>신촌 맛집</b> 아소비바 등심 안심카츠 돈까스',
#    'link': 'https://blog.naver.com/jjakggung/223299322077',
#    'description': '특별활동을 일찍 끝난 딸과 함께 오랫만에 신촌나들이, 맛나는 돈까스 먹고, 홍익문고 들려 문구 한가득 담고, 스벅에서 커피로 마무리까지... 날씨가 추워서 어떨까 싶었는데 이런것도 추억!!! <b>신촌 맛집</b>... ',
#    'bloggername': '더 이상 뚱뚱하지 않을 다이어리;노뚱줌의 식도락여행',
#    'bloggerlink': 'blog.naver.com/jjakggung',
#    'postdate': '20231221'},
#   {'title': '<b>신촌맛집</b> 신촌칼국수 김광석 신촌칼국수',
#    'link': 'https://blog.naver.com/crew0729/223330709774',
# ...

# %% [markdown]
# ## imdb

# %%
url = "https://www.imdb.com/chart/top/?ref_=nv_mv_250"

headers = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language" : "en-US"
}
res = requests.get(url, headers = headers)

# %%
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, "lxml")

# %%
for i in soup.select("ul > li h3.ipc-title__text"):
    print(i.string)
# Out:
# 1. The Shawshank Redemption
# 2. The Godfather
# 3. The Dark Knight
# 4. The Godfather Part II
# 5. 12 Angry Men
# 6. Schindler's List
# 7. The Lord of the Rings: The Return of the King
# 8. Pulp Fiction
# 9. The Lord of the Rings: The Fellowship of the Ring
# 10. The Good, the Bad and the Ugly
# 11. Forrest Gump
# 12. Fight Club
# 13. The Lord of the Rings: The Two Towers
# 14. Inception
# 15. Star Wars: Episode V - The Empire Strikes Back
# 16. The Matrix
# 17. Goodfellas
# 18. One Flew Over the Cuckoo's Nest
# 19. Se7en
# 20. It's a Wonderful Life
# 21. Interstellar
# 22. Seven Samurai
# 23. The Silence of the Lambs
# 24. Saving Private Ryan
# 25. City of God
# 26. Life Is Beautiful
# 27. The Green Mile
# 28. Terminator 2: Judgment Day
# 29. Star Wars: Episode IV - A New Hope
# 30. Spider-Man: Across the Spider-Verse
# 31. Back to the Future
# 32. Spirited Away
# 33. The Pianist
# 34. Parasite
# 35. Psycho
# 36. Gladiator
# 37. The Lion King
# 38. Léon: The Professional
# ...

# %% [markdown]
# # 약국 정보 조회

# %%
import json
import xmltodict

url = "http://apis.data.go.kr/B552657/ErmctInsttInfoInqireService/getParmacyListInfoInqire"

params = {
    "ServiceKey" :"JS7jeuof+pwfeEbRwoql+Wry6jw2GgIJlD3GWpVjjxNvEQSSGIc6HaD90Rg3u48tnw6LVidKVigCK2YAxGc4Hw==",
    "pageNo" : 1,
    "numOfRows" : 10
}
res = requests.get(url, params = params)
json = xmltodict.parse(res.content)

# %%
json["response"]["body"]["items"]["item"]
# Out:
# [{'dutyAddr': '경기도 안양시 만안구 박달로 518 (박달동)',
#   'dutyName': '1(일)약국',
#   'dutyTel1': '031-468-3354',
#   'dutyTime1c': '2000',
#   'dutyTime1s': '0900',
#   'dutyTime2c': '2000',
#   'dutyTime2s': '0900',
#   'dutyTime3c': '2000',
#   'dutyTime3s': '0900',
#   'dutyTime4c': '2000',
#   'dutyTime4s': '0900',
#   'dutyTime5c': '2000',
#   'dutyTime5s': '0900',
#   'dutyTime6c': '1700',
#   'dutyTime6s': '0900',
#   'hpid': 'C2101741',
#   'postCdn1': '140',
#   'postCdn2': '09',
#   'rnum': '1',
#   'wgs84Lat': '37.40242465877038',
#   'wgs84Lon': '126.9102104886459'},
#  {'dutyAddr': '경기도 남양주시 오남읍 양지로 47-63',
#   'dutyName': '1,2,3약국',
#   'dutyTel1': '031-529-8099',
#   'dutyTime1c': '1800',
#   'dutyTime1s': '0900',
#   'dutyTime2c': '1800',
#   'dutyTime2s': '0900',
#   'dutyTime3c': '1800',
#   'dutyTime3s': '0900',
#   'dutyTime4c': '1800',
#   'dutyTime4s': '0900',
#   'dutyTime5c': '1800',
#   'dutyTime5s': '0900',
#   'dutyTime6c': '1300',
#   'dutyTime6s': '0900',
# ...

# %%
url = "http://apis.data.go.kr/B552657/ErmctInsttInfoInqireService/getParmacyListInfoInqire"

params = {
    "ServiceKey" :"JS7jeuof+pwfeEbRwoql+Wry6jw2GgIJlD3GWpVjjxNvEQSSGIc6HaD90Rg3u48tnw6LVidKVigCK2YAxGc4Hw==",
    "pageNo" : 1,
    "numOfRows" : 1000,
    "Q0" : "서울특별시",
    "Q1" : "마포구"    
}
res = requests.get(url, params = params)
json = xmltodict.parse(res.content)
json
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'dutyAddr': '서울특별시 마포구 월드컵북로 230, 201호 (중동, 현대상가)',
#       'dutyMapimg': '현대상가 201호',
#       'dutyName': '2층하늘약국',
#       'dutyTel1': '02-303-4290',
#       'dutyTime1c': '1830',
#       'dutyTime1s': '0930',
#       'dutyTime2c': '1830',
#       'dutyTime2s': '0930',
#       'dutyTime3c': '1830',
#       'dutyTime3s': '0930',
#       'dutyTime4c': '1830',
#       'dutyTime4s': '0930',
#       'dutyTime5c': '1830',
#       'dutyTime5s': '0930',
#       'dutyTime6c': '1400',
#       'dutyTime6s': '0930',
#       'hpid': 'C1104164',
#       'postCdn1': '039',
#       'postCdn2': '41',
#       'rnum': '1',
#       'wgs84Lat': '37.570140470944516',
#       'wgs84Lon': '126.90383356849008'},
#      {'dutyAddr': '서울특별시 마포구 백범로 199, 메트로디오빌빌딩 108호 (신공덕동)',
#       'dutyName': '365열린약국',
#       'dutyTel1': '02-6010-2720',
#       'dutyTime1c': '2100',
# ...

# %%
for i in json["response"]["body"]["items"]["item"]:
    if "dutyTime2c" in i:
        if int(i["dutyTime2c"]) > 2000 :
            print(i['dutyName'],i['dutyTime2c'])
# Out:
# 365열린약국 2100
# delight이화약국 2100
# 건강약국 2100
# 고래약국 2300
# 공덕역마트약국 2030
# 공덕오거리약국 2100
# 광명약국 2030
# 나무약국 2100
# 늘푸른약국 2100
# 다나약국 2200
# 대교약국 2100
# 대흥365약국 2200
# 더블유스토어연세약국 2100
# 독일약국 2100
# 동경약국 2200
# 롱약국 2230
# 마래푸약국 2200
# 마포보건약국 2100
# 마포삼성약국 2100
# 마포온누리약국 2100
# 마포초록약국 2100
# 망원동약국 2100
# 망원시장약국 2230
# 망원우리약국 2100
# 매일여는약국 2400
# 메디칼약국 2130
# 메디컬성모약국 2100
# 메디팜신마포약국 2100
# 명치약국 2030
# 미소가득한약국 2200
# 비온뒤숲속약국 2500
# 비타민약국 2100
# 새봄약국 2100
# 샘터약국 2200
# 서교연세약국 2030
# 셀약국 2500
# 소망약국 2100
# 수약국 2100
# 신일약국 2230
# 아름다운약국 2200
# 아현종로약국 2100
# 애오개약국 2100
# 연남약국 2300
# 연세약국 2200
# 오아시스약국 2600
# 오즈약국 2030
# 온누리약국 2200
# 옵티마상원약국 2100
# 옵티마유한약국 2100
# 용약국 2100
# 우리약국 2200
# 우정옵티마약국 2100
# 유진온누리약국 2100
# 이로운약국 2030
# 이화메세나약국 2030
# 일출약국 2130
# 정아약국 2100
# 제일약국 2100
# 종오약국 2130
# 중원약국 2100
# 지선약국 2130
# 참약국 2300
# 참조은약국 2100
# 청심약국 2100
# 태평양약국 2300
# 파마트엘지약국 2100
# 프라자약국 2030
# 플러스약국 2130
# 한우리약국 2100
# 합정365약국 2130
# 합정녹십자약국 2100
# 합정동산약국 2200
# 합정스타약국 2230
# 햇살약국 2030
# 현정약국 2100
# ...
