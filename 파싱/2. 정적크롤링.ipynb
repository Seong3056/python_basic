# %% [markdown]
# # 정적 크롤링 모듈

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# - 요청 모듈로 가져온 HTML 코드를 파이썬이 쓸 수 있는 형태로 변환해주는 역할

# %%
url = "https://www.naver.com"
page = urlopen(url)
soup = BeautifulSoup(page, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"/> <meta content="index,nofollow" name="robots"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED-EDIT","title":"미나리전 ","url":"https://blog.naver.com/cckrecipe/223315104564","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20240117_1095/upload_1705487979551RuVpT.jpg"},"highlight":"레시피 집중탐구","desc":"맛과 멋 제대로 살린","desc2":"막걸리 안주로 안성맞춤","_id":"654ad80598c6dbca70ba6ce7"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"보지 마세요! 나만 알고 싶은 레전드 순대 5","url":"https://post.naver.com/viewer/postView.naver?volumeNo=37124897&memberNo=31740578","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20240117_1095/upload_1705487830770xh6q9.jpg"},"highlight":"푸드스토리","desc":"활용하기 좋은 '순대'","desc2":"지역 따라 다채롭게 즐겨요","_id":"654ad80598c6dbca70ba6ce8"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"촉촉하게 윤기가 흐르는 '코다리 무 조림' ","url":"https://tv.naver.com/v/45158073","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20240117_1095/upload_1705490389020bMG5f.jpg"},"highlight":"오늘의 푸드TV","desc":"양념장에 식용유 추가하면 ","desc2":"부드럽고 윤기나게 완성","video":{"playTime":"03:31"},"_id":"654ad80598c6dbca70ba6ce9"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"orderRandom":false,"_id":null,"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":"PC-FEED-RECIPE-CAS-EDIT","@template":"PC-FEED-CAS-EDIT","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"시금치 프리타타 만드는 법 토마토 에그프리타타 계란 오믈렛 만들기","url":"https://blog.naver.com/sallee_jaeryun/223310267789","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNDAxMDJfNzAg%2FMDAxNzA0MTgwNDg2Mjc4.7vOlwrgEiUDkeWpWtKsx5D_n0CMFmFv5guhTWsDUzE0g.UyL2KLusKYSDpCogklP1PMdIqEQIFNOY6Dmyc1o6nj0g.JPEG.moonra84%2FDSC_0811.JPG%22&type=nf308_200&service=navermain"},"source":{"url":"https://blog.naver.com/sallee_jaeryun","name":"살리재련","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2F20210419_199%2Fmoonra84_1618812430262R0pzc_JPEG%2Fprofileimage.jpg%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c56a"},{"@type":"MATERIAL-PC-FEED","title":"제육볶음 레시피 양념 고기 만들기 재우기 돼지고기 제육볶음","url":"https://in.naver.com/lovetogapyjs/contents/internal/650074444723936","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNDAxMTFfMjA0%2FMDAxNzA0OTY1Mjg1ODY0.PEr0Xt1NNalvEQfv7gAiwSXyTgBJfruCApsJ-pMbND8g.Y067DqwKLoFY-Yese0m8Ak1-R1oCBhaPT2gVSTzPUpUg.JPEG.lovetogapyjs%2FIMG_0028.JPG%22&type=nf308_200&service=navermain"},"source":{"url":"https://blog.naver.com/lovetogapyjs","name":"별공이","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyMDExMTBfODMg%2FMDAxNjA0OTU4MjI2OTU2.KnmaBrV2F-qY9dZAWqQtfqkhCTtpWxPyPupiAjPoO_kg.6hM4xW_uDE4YwlUNxMLq_jVZG1kU7969LyWeKo62ISsg.JPEG.lovetogapyjs%2FIMG_9759.JPG%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c56b"},{"@type":"MATERIAL-PC-FEED","title":"돼지갈비찜 레시피, 간장돼지갈비찜 양념 만들기","url":"https://in.naver.com/yimi0505/contents/internal/624721832495456","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzEwMzBfOTIg%2FMDAxNjk4NjI2NTExOTAx.0uDTnBSxBajV9QTr5TMywKqCPdmOPInMif2n5_RiJekg.021OZUyrv2A2_l9Wv3xhHFksvbfn52CBHIYZFIm3-k8g.JPEG.yimi0505%2FDSC08631.JPG%22&type=nf308_200&service=navermain"},"source":{"url":"https://blog.naver.com/yimi0505","name":"밍기맘마","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2F20160908_40%2Fyimi0505_1473333866649DOW8U_JPEG%2FprofileImage.jpg%22&type=nf40_ ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"a3c39ec0-b5d2-11ee-93d0-23357b0ab01e","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,39,71000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 16:00:13","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 17:32:05","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 10:17:28","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/353.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/353.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 07:46:13","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 15:00:00","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 12:56:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 15:55:07","_id":null,"@type":"PC-NEWS ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"대통령실 \"대규모 세수 축소 없는 부분 위주로 세금체계 개선\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453120","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"파키스탄, 이틀만에 이란 보복 공습…\"여성·아동 등 7명 사망\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453012","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbb"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"與, 아빠도 유급 출산휴가 한달…육아휴직급여 60만원 인상","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453432","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbc"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"野 \"둘 낳으면 24평 임대주택 제공…8∼17세 자녀당 월 20만원\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014452926","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbd"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"與 일각 \"김여사 명품백 사실관계 설명하고 사과해야\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453469","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbe"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"與, 이태원참사특별법 '尹거부권 행사' 건의…野에 재협상 제안","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453499","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbf"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"檢, '분당 흉기난동' 최원종에 사형 구형…\"잔인한 반인륜 범행\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453463","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dc0"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'을지대병원 태움' 가해 간호사 항소심도 실형…법정구속","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453470","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6573c24ecaf3d87b7e4d5269"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"인권조례 논란 이어 조희연 2심 유죄까지…흔들리는 진보교육","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453281","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65a2ab3683266959d97c94d3"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"조국, 울산시장 선거개입 재수사에 \"끝 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701260518p6pDo.png","image":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701256033PnhCQ.png","url":"https://chzzk.naver.com/","alt":"치지직"},"exposure":true,"@miniContentId":"659bad5a94eec44065226b83","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2024-01-08 00:00","@endAt":"2024-02-08 23:59","@createdAt":"2024-01-08T17:07:54.715","@updatedAt":"2024-01-08T17:07:54.715"},{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701318156pt3FO.png","image":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_17047013121634Q4Cs.png","url":"https://chzzk.naver.com/","alt":"치지직"},"exposure":true,"@miniContentId":"659bad873b6eb61b8bd23dbd","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2024-01-08 00:00","@endAt":"2024-02-08 23:59","@createdAt":"2024-01-08T17:08:39.619","@updatedAt":"2024-01-08T17:08:39.619"}],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"a291fc82-b5d2-11ee-93d0-9507327c88d2","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,37,63000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"altText":"2023 카타르 아시안컵","darkImage":"https://s.pstatic.net/static/www/mobile/edit/20240110_1095/upload_1704851435106c5RLq.png","lightImage":"https://s.pstatic.net/static/www/mobile/edit/20240110_1095/upload_17048514254674MZPF.png","url":"https://sports.news.naver.com/kfootball/index"},"exposure":true,"@miniContentId":"659df805616d6b26850941d8","@miniContentCode":"PC-MEDIA-TAB-EVENT","@startAt":"2024-01-11 12:00","@endAt":"2024-02-13 23:59","@createdAt":"2024-01-10T10:51:01.674","@updatedAt":"2024-01-11T12:34:50.554"}],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"a9bb06fc-b5d2-11ee-8d17-55024644bf3d","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,49,84000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"9effae52-b5d2-11ee-ae00-153aebf1cef4","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,31,93000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2023-04-18T18:34:36.648"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ac492bfb-b5d2-11ee-8d17-cb08d004200c","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,53,365000000]}
# </script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.37930f2b.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.8c808364.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.e6d3b50c.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.5e714c50.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.259b1922.css" rel="stylesheet"/></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div> <script data-gfp-banner-size="1444x150" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"payload":{"requestId":"c06b639562d943feb806273ab1c11b15","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":73,"adDivId":"ad_timeboard","advertiserDomains":["www.samsung.com"],"adDuplicationKeys":["URL:https://www.samsung.com","NDP:Y"],"ads":[{"encrypted":"5UkHcDjs3nsUXi2YwJYnEyQqSLMNlQ8Z4K1yLRtjKmhLUJURNAEZHq5IYYAdoqaKoNGQSHPeAg01fcy3pkZFwVR0RZZz4dPwSJT5GKu3KmR8CNiQe_RvacUk9V37giZ2ECoqslEEQWJePctz2Anp7XcNEKIlFPWT41_WxgtcZcloTWMpxRLt_4UQ_-_n4JYqj9FC7i9NuV0PPqJa-AQjzJTqz26JwAEoZDi3MtlznD8mt-572nOYhfxwPE-SmiFNyvcicjjLAIprMWB2nCkQi26I4k8pEEhCqWYVsQKtZSVDWttqjNupSwrDRCEjo5a8KRtCDIDjkqMbEOk09ne3RN5qZAqAojLLG25QwAGO5Dv5eVBbkuir2P6i_lpJW1qNb4sJbrTsXVMaNJZE__q5aTJUubMhUnubJf7m2OWe_3sSAPuObm2_lFbMCKUWwujsuKnRDiBuBd_CB0hCO6cxAQ81Mp7sEd22iQt8al7GFmBPYHxGaGIvyJGN_szQjPC_1Sbycm5hRYcrYkFQOLth2Tc4mfm5HkQjJ9aVjW-Prd8rjthwitxdIVnOrHVK_Px3CIYRpqxrs9flXGrGrgf-Zi02N1ZTXPMCgo0z0Kc-j4LVGSShQniz8FSPkbLUesTD5LMqDNHNROzumgaRE46MrbDKRZCSRWT6Op7tfC-Wy30G4TGf-TSrE7Mjh4cKnXXeINy9W2CDCFsViRFs5AKE_X3hLhshoGnDjPP5nOb2lmHTdTB_L_qz9Kyi0c_SuywE","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5PaWXzpvWdqMVKandSRNstv0rpEPj4hVYre91xCmOlXZULpq2Cjte83JL1qM2Pf%2Fak82fMG5Q7uLdr9HzzWaFRWTCwLniO0%2BQ3IBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8910654\u0026src=6911604\u0026evtcd=BID_WIN\u0026x_ti=1500\u0026rk=ToEprr1rGXWcKHzo5ONO6A\u0026eltts=M7VOe9IHGuyjSr6Krc%2F7Sg%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["www.samsung.com"],"cid":"1478801","crid":"2593300","exp":2013,"adm":"%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs% ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="link_search_special" id="special-input-logo-ex" style="display:none"></div> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element=""> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근 검색어</strong> <div class="option"> <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"></ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"> <a class="close _keywordO ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240118162625',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var s=i&&i.content&&i.content.input&&i.content.input.placeholder;if(s){var o=document.getElementById("query");o&&s&&o.setAttribute("title",s),o&&s&&o.setAttribute("placeholder",s)}}()</script> </body> </html>

# %% [markdown]
# ## 파서
#
# - 내가 원하는 데이터를 특정패턴이나 순서로 추출하여 정보를 가공해주는 프로그램
#     - lxml
#         - c언어로 구현되어 속도가 가장 빠름
#     - html.parser
#         - lxml과 html5lib의 중간 속도
#     - html5lib
#         - 웹브라우저 형태로 HTML을 분석
#         - 속도가 가장 느림
#         - 가장 안정적

# %%
# html을 예쁘게 출력
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="NAVER" name="apple-mobile-web-app-title"/>
#   <meta content="index,nofollow" name="robots"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
#   <meta content="네이버" property="og:title"/>
#   <meta content="https://www.naver.com/" property="og:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="https://www.naver.com/" name="twitter:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/>
#   <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#   <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet"/>
#   <script>
#    window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#   </script>
#   <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js">
#   </script>
#   <script>
#    window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"비밀 시설에서 살아남기, ‘SCP 재단’ 게임 5선","url":"https://post.naver.com/viewer/postView.naver?volumeNo=37198156&memberNo=10582936&navigationType=push","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492095190yKCgm.jpg%22&type=f504_292&service=navermain"},"source":{"name":"게임메카","service":"POST","image":{"url":"https://s.pstatic.net/post.phinf/MjAxOTA1MjRfMjM5/MDAxNTU4NjYxNDQ5Mzk2.uF7tdcym-BfWVWLzL--C2tjYZ9nq3aT8ewo_SmD0-sIg.ecLq082WqECmiuytEP9cfMNiT7UFifqhcn4xO-8__R8g.JPEG/post_4926827793841172554.jpg?type=f120_120"}},"_id":"65308fd13c50cd9912162f6a"},{"@type":"MATERIAL-PC-FEED","title":"다음 이야기가 궁금해! 추리 어드벤처 '어나더 코드 리컬렉션: 2개의 기억/기억","url":"https://post.naver.com/viewer/postView.naver?volumeNo=37203454&memberNo=11878375&navigationType=push","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492232036dRc75.jpg%22&type=f504_292&service=navermain"},"source":{"name":"게임동아","service":"POST","image":{"url":"https://s.pstatic.net/post.phinf/20150313_148/gamedonga_1426242462746hob8d_JPEG/gmaeodn.jpg?type=f120_120"}},"_id":"65308fd13c50cd9912162f6b"},{"@type":"MATERIAL-PC-FEED","title":"‘나만의 피조물’로 플레이 경험 넓힌다, 디아블로 IV 시즌 3 인터뷰","url":"https://post.naver.com/viewer/postView.naver?volumeNo=37199053&memberNo=11710666&navigationType=push","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492185465TcjZQ.jpg%22&type=f504_292&service=navermain"},"source":{"name":"게임어바웃","service":"POST","image":{"url":"https://s.pstatic.net/post.phinf/MjAxOTA0MDRfMTMy/MDAxNTU0MzY5ODY1NDk0.qqZk9E76FyJp7s_4AY7Yc57vMoOp4yXlSoqmchJLWPsg.aTx1y3gBn51DTAcWdNyedmI_JZ5p1lRahx0v2sjXHPQg.PNG/post_4904537904033771516.png?type=f120_120"}},"_id":"654ad80598c6dbca70ba6ce6"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@template":"NONE"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@code":"PC-FEED-GAMEAPP-HOT-STORY","@template":"HIGHLIGHTED-COLUMNS"},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"활기찬 치어리딩! 카드캡터 체리 치어리더 코스프레!","url":"https://game.naver.com/original_series/33/temp/104626","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492293103Mov3z.jpg%22&type=nf308_200&service=navermain"},"source":{"name":"팀하라 코스프레"},"_id":"6441ca92c499cc07f334c4b3"},{"@type":"MATERIAL-PC-FEED","title":"대장내시경을 통한 스토리 게임..? 'Revenge Of The Colon'","url":"https://game.naver.com/original_series/32/temp/104831","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492366291qnmEc.jpg%22&type=nf308_200&service=navermain"},"source":{"name":"게임인"},"_id":"6441ca92c499cc07f334c4b4"},{"@type":"MATERIAL-PC-FEED","title":"위기의 e스포츠에서 수익화 구현을 위한 제언 - 오프라인","url":"https://game.naver.com/original_series/27/temp/105284","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492442739MAHxo.jpg%22&type=nf308_200&service=navermain"},"source":{"name":"Periodista"},"_id":"6441ca92c499cc07f334c4b5"},{"@type":"MATERIAL-PC-FEED","title":"“화면은 작아지고 휴대성은 높이고”, 게임환경이 바뀐다","url":"https://game.naver.com/original_series/28/temp/104858","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240117_1095%2Fupload_1705492483838uf3 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c789cac9-b5d2-11ee-ae00-c11e2451029d","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,25,39,109000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 16:20:12","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 17:32:05","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 10:17:28","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/353.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/353.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 07:46:13","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 16:00:00","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 12:56:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240118 15:55:07","_id":null,"@type":"PC-NEWS ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"대통령실 \"대규모 세수 축소 없는 부분 위주로 세금체계 개선\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453120","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"파키스탄, 이틀만에 이란 보복 공습…\"여성·아동 등 7명 사망\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453012","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbb"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"與, 아빠도 유급 출산휴가 한달…육아휴직급여 60만원 인상","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453432","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbc"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"野 \"둘 낳으면 24평 임대주택 제공…8∼17세 자녀당 월 20만원\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014452926","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbd"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"與 일각 \"김여사 명품백 사실관계 설명하고 사과해야\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453469","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbe"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"與, 이태원참사특별법 '尹거부권 행사' 건의…野에 재협상 제안","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453499","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbf"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"檢, '분당 흉기난동' 최원종에 사형 구형…\"잔인한 반인륜 범행\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453463","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dc0"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'을지대병원 태움' 가해 간호사 항소심도 실형…법정구속","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453470","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6573c24ecaf3d87b7e4d5269"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"인권조례 논란 이어 조희연 2심 유죄까지…흔들리는 진보교육","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014453281","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65a2ab3683266959d97c94d3"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"조국, 울산시장 선거개입 재수사에 \"끝 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701260518p6pDo.png","image":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701256033PnhCQ.png","url":"https://chzzk.naver.com/","alt":"치지직"},"exposure":true,"@miniContentId":"659bad5a94eec44065226b83","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2024-01-08 00:00","@endAt":"2024-02-08 23:59","@createdAt":"2024-01-08T17:07:54.715","@updatedAt":"2024-01-08T17:07:54.715"},{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701318156pt3FO.png","image":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_17047013121634Q4Cs.png","url":"https://chzzk.naver.com/","alt":"치지직"},"exposure":true,"@miniContentId":"659bad873b6eb61b8bd23dbd","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2024-01-08 00:00","@endAt":"2024-02-08 23:59","@createdAt":"2024-01-08T17:08:39.619","@updatedAt":"2024-01-08T17:08:39.619"}],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c658027d-b5d2-11ee-ae00-5780c5061094","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,25,37,93000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"altText":"2023 카타르 아시안컵","darkImage":"https://s.pstatic.net/static/www/mobile/edit/20240110_1095/upload_1704851435106c5RLq.png","lightImage":"https://s.pstatic.net/static/www/mobile/edit/20240110_1095/upload_17048514254674MZPF.png","url":"https://sports.news.naver.com/kfootball/index"},"exposure":true,"@miniContentId":"659df805616d6b26850941d8","@miniContentCode":"PC-MEDIA-TAB-EVENT","@startAt":"2024-01-11 12:00","@endAt":"2024-02-13 23:59","@createdAt":"2024-01-10T10:51:01.674","@updatedAt":"2024-01-11T12:34:50.554"}],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"a9bb06fc-b5d2-11ee-8d17-55024644bf3d","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,49,84000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"c2c9ab8b-b5d2-11ee-ae00-67346d5b4a05","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,25,31,120000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2023-04-18T18:34:36.648"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ac492bfb-b5d2-11ee-8d17-cb08d004200c","@provider":"lambda","@lastModifiedAt":[2024,1,18,7,24,53,365000000]}
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.37930f2b.js?o=www">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.8c808364.js?o=www">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.e6d3b50c.js?o=www">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.5e714c50.js?o=www">
#   </script>
#   <link href="https://pm.pstatic.net/resources/css/main.259b1922.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div id="u_skip">
#    <a href="#topAsideButton">
#     <span>
#      상단영역 바로가기
#     </span>
#    </a>
#    <a href="#shortcutArea">
#     <span>
#      서비스 메뉴 바로가기
#     </span>
#    </a>
#    <a href="#newsstand">
#     <span>
#      새소식 블록 바로가기
#     </span>
#    </a>
#    <a href="#shopping">
#     <span>
#      쇼핑 블록 바로가기
#     </span>
#    </a>
#    <a href="#feed">
#     <span>
#      관심사 블록 바로가기
#     </span>
#    </a>
#    <a href="#account">
#     <span>
#      MY 영역 바로가기
#     </span>
#    </a>
#    <a href="#widgetboard">
#     <span>
#      위젯 보드 바로가기
#     </span>
#    </a>
#    <a href="#viewSetting">
#     <span>
#      보기 설정 바로가기
#     </span>
#    </a>
#   </div>
#   <script data-gfp-banner-size="1444x150" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">
#    {"payload":{"requestId":"ae9c003f71664a93a5a79086d8f3df09","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":31,"adDivId":"ad_timeboard","advertiserDomains":["www.samsung.com"],"adDuplicationKeys":["URL:https://www.samsung.com","NDP:Y"],"ads":[{"encrypted":"ohifmgCXDFuw0T-3L5Gl05nKWF9kXQFe2EXLVQkyMoRcjzh_Nl8IvvJZJyk-GuT8OCn7W2pk7CXmz0AFKbMsy7tXz1hUnxYEK9Wdc8WWZOrtoNH9ERMhGNvbaVLOzLi9UyReOByIAOzo5WvrBxwG3j2qszs0Ulm3skxsp-ikHyvx9feP0Pi7zfjMSbZqgvdwcmrOFJvxx-apOhZesAbuLOpKKfTp-aVVz9RhBeOpnlKbDJ0x4a3gFKm9IxY2Zq4-LTv-YPa7rG7EAjOsoeJza1JIxT7ktBjbTJE1XlC8JLUKznFNf1UInkerpugrMSK-UzNollqZN5_P_ibn_zyndq-hwjL4QK-_OrbI12Q-QXXEnzRUfIdY11DDgTYZVrnbBQRi9qSW4aKWl5ikWMTDp17pU0hzNdyD5Mdbr-xxGfr_srz7twY_rvvjNJzBdopThKjx-vl1FhYf4h-8kQ36_U1eLiSkkWphFaYlK9gtldY9oYOs94GB0umpGgC7BF88ooLGvkOe9Ej5XjzGawkzz5mi6yXkj_7hxntIvH3r0V3CbMENUJ2NmEOV4jpyFOpj7NP_UA3_ccGGZ4VceHcSmg55HddakzcOnt0SLV9ojMWIhv_B9L8iGjAVUNhb0kHHp3lYS4XUOSmYI960vgPZlPLZImL_2WpXe9cQmeGD-XFEPJaMV3qHF6R-wJQg1KEEjFYW0Ig-DZ2VuGOxdppV1VNKl4vfHxzaqkUDTvppB4OUBow_3XwtYaxUoJbw9o70","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5PDd%2FqJliTXGruA5BwoeLQEylVOT40LHIgiEdV3x6u3IsgZT%2BJe9Tr%2FJL1qM2Pf%2Fak82fMG5Q7uLdr9HzzWaFRWIjAWIZ0IrlvIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8910654\u0026src=6911604\u0026evtcd=BID_WIN\u0026x_ti=1500\u0026rk=iuXJHiU-t5zKzNe6RhogOg\u0026eltts=N9k1ZHf6hnStPO%2Byu3l4Ow%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["www.samsung.com"],"cid":"1478801","crid":"2593300","exp":1940,"adm":"%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fjs%2Fpc%2Fmain%2Fmin%2Fpc.veta.core.min.js%22%3E%3C%2Fscript%3E%0D%0A%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fglad%2Fbridge%2Fgfp-bridge.js%22%3E%3C%2Fscript%3E%0D%0A%3Cscript%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fjs%2Fpc%2Fmain%2Fmin%2Ftimeboard_premium_v202212.min.js%3F20230525%22%3E%3C%2Fscript%3E%0D%0A%3Clink%20href%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fcss%2Fpc%2Fmain%2Fmin%2Ftimeboard_premium_v202212.min.css%3F20230524%22%20rel%3D%22stylesheet%22%3E%0D%0A%3Cstyle%3E%0D%0A%09%40media%20%28max-width%3A%201000px%29%20%7B%0D%0A%09%09%2F%2A%20%EC%82%AC%EC%9D%B4%EC%A6%88%20%EC%A1%B0%EC%A0%95%EC%9D%80%20976px%20%EB%98%90%EB%8A%94%201480px%20%EC%9D%B4%EC%83%81%EC%9D%B8%20%EA%B2%BD%EC%9A%B0%EB%A7%8C%20%EC%A1%B4%EC%9E%AC.%20%EA%B7%B8%EB%9E%98%EC%84%9C%20%EA%B7%B8%20%EC%82%AC%EC%9D%B4%EA%B0%92%201000px%EB%A1%9C%20%EC%A7%80%EC%A0%95.%20%EC%B0%B8%EA%B3%A0%3A%20976px%EC%9C%BC%EB%A1%9C%20%EC%A7%80%EC%A0%95%ED%95%98%EB%A9%B4%20%EC%97%A3%EC%A7%80%EC%97%90%EC%84%9C%20%EC%9D%B8%EC%8B%9D%EB%90%98%EC%A7 ...
#   </script>
#   <div id="wrap">
#    <div id="header" role="banner">
#     <div class="header_inner" id="topSearchWrap">
#      <div class="search_special_bg" id="special-logo">
#      </div>
#      <div class="ad_area" id="timeboard-ex" style="min-width:1340px">
#      </div>
#      <div class="search_area" id="search_area" style="border-color:#fff">
#       <div class="link_search_special" id="special-input-logo-ex" style="display:none">
#       </div>
#       <div class="search_group">
#        <div class="search_group_inner" id="search">
#         <h1 class="search_logo" id="special-input-logo">
#         </h1>
#         <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search">
#          <fieldset>
#           <legend class="blind">
#            검색
#           </legend>
#           <input name="where" type="hidden" value="nexearch"/>
#           <input id="sm" name="sm" type="hidden" value="top_hty"/>
#           <input id="fbm" name="fbm" type="hidden" value="0"/>
#           <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
#           <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
#           <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#           <input id="ie" name="ie" type="hidden" value="utf8"/>
#           <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#           <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#           <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#           <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#           <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#           <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#           <div class="search_input_box">
#            <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/>
#           </div>
#           <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit">
#            <span class="ico_btn_search_svg">
#             <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z">
#              </path>
#             </svg>
#            </span>
#            <span class="blind">
#             검색
#            </span>
#           </button>
#          </fieldset>
#         </form>
#         <div class="search_box">
#          <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button">
#           <span class="keybord_text">
#            <span class="blind">
#             입력도구
#            </span>
#           </span>
#          </button>
#          <div id="_nx_kbd" style="display:none">
#          </div>
#          <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button">
#           <span class="blind">
#            자동완성/최근검색어펼치기
#           </span>
#          </button>
#         </div>
#         <div class="layer_atcmp" id="autoFrame" style="display:none">
#          <div class="ly_atcmp" data-atcmp-element="">
#           <div class="api_atcmp_wrap">
#            <div class="atcmp_fixer _recent_layer" style="display:none">
#             <div class="atcmp_header _recent_header">
#              <strong class="tit">
#               최근 검색어
#              </strong>
#              <div class="option">
#               <a aria-pressed="false" class="item _delAll" href="#" role="button">
#                전체삭제
#               </a>
#              </div>
#             </div>
#             <div class="atcmp_container">
#              <ul class="kwd_lst _recent">
#              </ul>
#              <div class="kwd_info kwd_off _offMsg" style="display:none">
#               검색어 저장 기능이 꺼져 있습니다.
#               <br/>
#               <span class="kwd_dsc">
#                설정이 초기화 된다면
#                <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">
#                 도움말
#                </a>
#                을 확인해주세요.
#               </span>
#              </div>
#              <div class="kwd_info kwd_none _recentNone" style="display:none">
#               최근 검색어 내역이 없습니다.
#               <br/>
#               <span class="kwd_dsc">
#                설정이 초기화 된다면
#                <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">
#                 도움말
#                </a>
#                을 확인해주세요.
#               </span>
#              </div>
#             </div>
#             <div class="atcmp_footer">
#              <span class="side_opt_area">
#               <span class="opt_item">
#                <a class="close _keywordOnOff" href="#">
#                 자동저장 끄기
#                </a>
#               </span>
#               <span class="opt_item">
#                <a data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">
#                 도움말
#                </a>
#               </span>
#              </span>
#              <span class="rside_opt_area">
#               <span class="opt_item">
#                <a class="close _close" href="#">
#                 닫기
#                </a>
#               </span>
#              </span>
#             </div>
#            </div>
#            <div class="atcmp_fixer _atcmp_layer" style="display:none">
#             <div class="atcmp_container _words">
#              <ul class="kwd_lst _kwd_list">
#              </ul>
#              <div class="atcmp_cue type_line _cue_root">
#               <div class="cue_header">
#                <i class="imgsvg ico_cue">
#                 CUE
#                </i>
#                대화하듯 질문해 보세요
#                <a aria-pressed="false" class="btn_help _tg_btn" href="#" role="button">
#                 <i class="imgsvg ico_alert">
#                  이 정보가 표시된 이유
#                 </i>
#                </a>
#                <div class="layer_plus">
#                 <p class="dsc">
#                  검색어와 포함된 키워드를 기반으로 AI 기술을 활용하여 연관된 추천 질문을 제공합니다.
#                 </p>
#                 <a class="btn_close _tg_btn" href="#" role="button">
#                  <i class="imgsvg ico_close">
#                   레이어 닫기
#                  </i>
#                 </a>
#                </div>
#               </div>
#               <ul class="cue_list _ul">
#               </ul>
#              </div>
#              <div class="atcmp_alert _alert">
#               <div class="dsc_election">
#                <p class="dsc">
#                 <i class="imgsvg ico_election">
#                 </i>
#                 <span class="_alert_passage">
#                 </span>
#                </p>
#                <span class="dsc_inner">
#                 <span class="_alert_passage2">
#                 </span>
#                 <a class="link _alert_link" href="#" target="_blank">
#                  자세히보기
#                 </a>
#                </span>
#               </div>
#              </div>
#              <div class="atcmp_plus _plus">
#               <div class="dsc_plus">
#                <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/alias/search/word/word_16.naver" target="_blank">
#                 관심사를 반영한 컨텍스트 자동완성
#                 <i class="imgsvg ico_help">
#                  도움말
#                 </i>
#                </a>
#               </div>
#               <div class="switch">
#                <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button">
#                 <i class="imgsvg ico_option">
#                  컨텍스트 자동완성
#                 </i>
#                </a>
#               </div>
#               <div class="layer_plus _plus_layer">
#                <strong class="tit">
#                 컨텍스트 자동완성
#                </strong>
#                <div class="_plus_layer_isloggedin" style="display:none">
#                 <p class="dsc">
#                  ON/OFF 설정은 해당기기(브라우저)에 저장됩니다.
#                 </p>
#                 <div class="btn_area">
#                  <a class="link_view" data-clk="sug.cxlink" href="https://help.naver.com/alias/search/word/word_16.naver" target="_blank">
#                   자세히 보기
#                  </a>
#                 </div>
#                </div>
#                <div class="_plus_layer_isnotloggedin" style="display:none">
#                 <p class="dsc">
#                  동일한 시간대・연령대・남녀별 사용자 그룹의 관심사에 맞춰 자동완성을 제공합니다.
#                  <a class="link_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                   자세히 보기
#                  </a>
#                 </p>
#                 <div class="btn_area">
#                  <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">
#                   <i class="imgsvg ico_naver">
#                    네이버
#                   </i>
#                   로그인
#                  </a>
#                 </div>
#                </div>
#                <a class="btn_close _plus_layer_close" href="#" role="button">
#                 <i class="imgsvg ico_close">
#                  컨텍스트 자동완성 레이어 닫기
#                 </i>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="atcmp_footer">
#              <span class="side_opt_area">
#               <span class="opt_item">
#                <a class="close _suggestOnOff" href="#">
#                 자동완성 끄기
#                </a>
#               </span>
#               <span class="opt_item">
#                <a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">
#                 도움말
#                </a>
#               </span>
#               <span class="opt_item">
#                <a class="report" data-clk="sug.report" href="https://help.naver.com/alias/search/word/word_18.naver" target="_blank">
#                 신고
#                </a>
#               </span>
#              </span>
#              <span class="rside_opt_area">
#               <span class="opt_item">
#                <a class="close _close" href="#">
#                 닫기
#                </a>
#               </span>
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="search-right-banner">
#      </div>
#      <div class="shortcut_area" id="shortcutArea" role="region">
#      </div>
#      <div class="menu_area" id="topAsideArea">
#      </div>
#      <div class="pay_area" id="topPayArea">
#      </div>
#      <div class="talk_area" id="topTalkArea">
#      </div>
#      <div class="notify_area" id="topNotiArea">
#      </div>
#     </div>
#    </div>
#    <div id="container" role="main">
#     <div id="root">
#     </div>
#    </div>
#    <div id="footer" role="contentinfo">
#    </div>
#   </div>
#   <script>
#    window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240118162738',  };
#   </script>
#   <script>
#    !function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var s=i&&i.content&&i.content.input&&i.content.input.placeholder;if(s){var o=document.getElementById("query");o&&s&&o.setAttribute("title",s),o&&s&&o.setAttribute("placeholder",s)}}()
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## 속성 데이터

# %%
html = """<html><head> <title class="t" id="ti">test site</title> </head><body> <p>test</p> <p>test1</p> <p>test2</p> </body></html>
"""

# %% [markdown]
# - html
#     - head
#         - title
#             - 속성
#                 - class: t
#                 - id: ti
#     - body
#         - p
#         - p
#         - p

# %%
soup = BeautifulSoup(html, "lxml")

# %%
print(soup)
# Out:
# <html><head> <title class="t" id="ti">test site</title> </head><body> <p>test</p> <p>test1</p> <p>test2</p> </body></html>

# %%
tag_title = soup.title # soup 안에서 title 태그 찾기

# %%
print(tag_title)
print(tag_title.attrs) # 태그의 속성 가져오기
print(tag_title["class"]) # 키가 없으면 에러발생
print(tag_title["id"])
# Out:
# <title class="t" id="ti">test site</title>
# {'class': ['t'], 'id': 'ti'}
# ['t']
# ti

# %%
tag_title["class1"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tag_title["class1"]
#
# NameError: name 'tag_title' is not defined

# %%
# tag 타입은 딕셔너리처럼 접근할 수 있고 딕셔너리 문법을 그대로 적용할 수 있음
tag_title.get("class1","default_value")
# Out:
# 'default_value'

# %%
type(tag_title)
# Out:
# bs4.element.Tag

# %% [markdown]
# ### 태그 접근

# %%
tag_title = soup.title # title 태그
print(tag_title)
# Out:
# <title class="t" id="ti">test site</title>

# %%
print(tag_title.text)
print(tag_title.string)
print(tag_title.name)
# Out:
# test site
# test site
# title

# %%
# text와 string의 차이
html = """<html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - p
#             - span
#             - span

# %%
soup = BeautifulSoup(html, 'lxml')

tag_p = soup.p

data_text = tag_p.text
data_string = tag_p.string

print(data_text, type(data_text))
print(data_string, type(data_string))
# Out:
# test1test2 <class 'str'>
# None <class 'NoneType'>

# %% [markdown]
# - text : 하위 태그들의 값도 모두출력
# - string : 정확히 해당 태그에 대한 값만 출력

# %%
# string으로 test1을 출력하려면
tag_p.span.string
# Out:
# 'test1'

# %% [markdown]
# ### 자식 태그 접근
#
# - content와 children 속성을 이용하여 자식태그 가져오기

# %%
tag_p_children = soup.p.contents
print(tag_p_children)
# Out:
# [<span>test1</span>, <span>test2</span>]

# %%
tag_p_children = soup.p.children # children으로 가져온 값은 반복문을 사용해야함

for child in tag_p_children:
    print(child)
# Out:
# <span>test1</span>
# <span>test2</span>

# %% [markdown]
# ### 부모 태그 접근
#
# - parent와 parents 로 부모태그 가져오기

# %%
tag_span = soup.span
tag_title = soup.title

span_parent = tag_span.parent
title_parent = tag_title.parent

print(span_parent)
print(title_parent)
# Out:
# <p><span>test1</span><span>test2</span></p>
# <head><title>test site</title></head>

# %%
span_parents = tag_span.parents
title_parents = tag_title.parents

for parent in span_parents:
    print(parent)
print()
for parent in title_parents:
    print(parent)
# Out:
# <p><span>test1</span><span>test2</span></p>
# <body> <p><span>test1</span><span>test2</span></p> </body>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>
#
# <head><title>test site</title></head>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>

# %% [markdown]
# ### 형제 태그 접근
#
# - 형제 태그 : 동등한 위치의 태그

# %%
tag_span
# Out:
# <span>test1</span>

# %%
a = tag_span.next_sibling
print(a)
# Out:
# <span>test2</span>

# %%
b = a.previous_sibling
print(b)
# Out:
# <span>test1</span>

# %%
print(a.next_sibling)
print(b.previous_sibling)
# Out:
# None
# None

# %% [markdown]
# ### 다음 요소, 이전 요소 접근하기
#
# - next_element, previous_element
# - 형제 태그와의 차이
#     - 형제 태그 : 동일한 위치의 태그들만
#     - 요소 : 태그도 포함하지만 그 안의 자식태그와 문자도 포함하는 개념

# %%
html = """<html> <head><title>test site</title></head> <body> <p><a>test1</a><b>test2</b><c>test3</c></p> </body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - p
#             - a
#             - b
#             - c

# %%
soup = BeautifulSoup(html,'lxml')
tag_a = soup.a
tag_a
# Out:
# <a>test1</a>

# %%
tag_a_nexts = tag_a.next_elements
for tag in tag_a_nexts:
    print (tag)
# Out:
# test1
# <b>test2</b>
# test2
# <c>test3</c>
# test3

# %% [markdown]
# ## 원하는 요소에 접근하기
#
# - find_all()
#     - 원하는 태그들을 리스트 형태로 가져오기

# %%
html = """
<html>
<head>
<title>test site</title>
</head> 
<body>
<p id="i" class="a">test1</p>
<p id="d" class="d">test2</p>
<p class="c">test3</p>
</p>
<a>a tag</a> 
<b>b tag</b>
</body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - p(id = i, class = a)
#         - p(id = d, class = d)
#         - p(class = c)
#         - p
#         - a
#         - b

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
soup.find_all("p")
# Out:
# [<p class="a" id="i">test1</p>,
#  <p class="d" id="d">test2</p>,
#  <p class="c">test3</p>]

# %% [markdown]
# - id 값으로 태그 가져오기

# %%
soup.find_all(id = "d")
# Out:
# [<p class="d" id="d">test2</p>]

# %%
# id의 존재여부로 데이터가져오기
print(soup.find_all(id = True))
# Out:
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>]

# %%
print(soup.body.find_all(id = False))
# Out:
# [<p class="c">test3</p>, <a>a tag</a>, <b>b tag</b>]

# %% [markdown]
# - 원하는 태그, 원하는 id 값으로 태그 가져오기

# %%
print(soup.find_all("p", id = "d"))
print(soup.find_all("p", id = "c"))
# Out:
# [<p class="d" id="d">test2</p>]
# []

# %% [markdown]
# - text 속성으로 태그 가져오기

# %%
print(soup.find_all("p", text = "test1")) # p 태그 중에서 test1 이라는 값을 가진태그
print(soup.find_all("p", text = "t"))
# Out:
# [<p class="a" id="i">test1</p>]
# []
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_15532\3261131605.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   print(soup.find_all("p", text = "test1")) # p 태그 중에서 test1 이라는 값을 가진태그
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_15532\3261131605.py:2: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   print(soup.find_all("p", text = "t"))

# %% [markdown]
# - limit로 가져오는 태그 수 제한

# %%
print(soup.find_all("p"))
# Out:
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>, <p class="c">test3</p>]

# %%
print(soup.find_all("p", limit = 1))
print(soup.find_all("p", limit = 2))
print(soup.find_all("p", limit = 5))
# Out:
# [<p class="a" id="i">test1</p>]
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>]
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>, <p class="c">test3</p>]

# %%
# find_all에 아무런값도 넣지않으면 모든 태그를 가져옴
soup.find_all()
# Out:
# [<html> <head><title>test site</title></head> <body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body></html>,
#  <head><title>test site</title></head>,
#  <title>test site</title>,
#  <body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body>,
#  <p class="a" id="i">test1</p>,
#  <p class="d" id="d">test2</p>,
#  <p class="c">test3</p>,
#  <a>a tag</a>,
#  <b>b tag</b>]

# %% [markdown]
# - 여러 태그 동시에 가져오기

# %%
soup.find_all(["a", "b"])
# Out:
# [<a>a tag</a>, <b>b tag</b>]

# %% [markdown]
# - find_all() 연속으로 사용하기

# %%
tag_body = soup.find_all("body")
print(tag_body)
tag_body[0].find_all("p")
# Out:
# [<body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body>]
# [<p class="a" id="i">test1</p>,
#  <p class="d" id="d">test2</p>,
#  <p class="c">test3</p>]

# %% [markdown]
# ### find()
# - 하나의 요소만 가져옴
# - 찾고자 하는 요소가 하나만 있을 때 사용
#     - 예) id값으로 접근

# %%
soup.find("p")
# Out:
# <p class="a" id="i">test1</p>

# %%
print(soup.find("p", class_ = "d"))
print(soup.find("p", id = "i"))
# Out:
# <p class="d" id="d">test2</p>
# <p class="a" id="i">test1</p>

# %%
# 연속으로 find() 사용
soup.find("body").find("p", class_ = "d")
# Out:
# <p class="d" id="d">test2</p>

# %% [markdown]
# ### select()
# - find_all()과 마찬가지로 매칭되는 모든 결과를 리스트로 반환
# - 클래스는 마침표(.), 아이드는 샵(#)으로 자손태그는 띄어쓰기로 표현 자식태그는 (>)로 표현
# - select_ one() 으로 하나의 결과만 반환하는 것도 가능

# %%
print(soup.select("p")) # p 태그들
print(soup.select(".d")) # 클래스가 d인 태그들
print(soup.select("p.d")) # 클래스가 d인 p태그들
print(soup.select("#i")) # 아이디가 i인 태그들
print(soup.select("p#i")) # 아이디가 i인 p태그
# Out:
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>, <p class="c">test3</p>]
# [<p class="d" id="d">test2</p>]
# [<p class="d" id="d">test2</p>]
# [<p class="a" id="i">test1</p>]

# %% [markdown]
# #### html = """
# <html>
#     <head>
#         <title>test site</title>
#     </head>
#     <body>
#         <div>
#             <p id="i" class="a">test1</p>
#             <p class="d">test2</p>
#         </div>
#         <p class="d">test3</p></p>
#         <a>a tag</a>
#         <b>b tag</b>
#     </body>
# </html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - div
#             - p(id = i, class = a)
#             - p(class = d)
#         - p(class = d)
#         - a
#         - b

# %%
soup = BeautifulSoup(html, "lxml")

# %%
print(soup.select("body p")) # body의 자손인 p태그들
print(soup.select("body > p")) # body의 자식인 p태그
# Out:
# [<p class="a" id="i">test1</p>, <p class="d">test2</p>, <p class="d">test3</p>]
# [<p class="d">test3</p>]

# %%
print(soup.select("body .d")) # body 자손이면서 클래스가 d인 태그들
# Out:
# [<p class="d">test2</p>, <p class="d">test3</p>]

# %%
print(soup.select("body p.d")) # body 자손이면서 클래스가 d인 p태그들
# Out:
# [<p class="d">test2</p>, <p class="d">test3</p>]

# %%
print(soup.select("body #i")) # body 자손이면서 id가 i인 태그들
# Out:
# [<p class="a" id="i">test1</p>]

# %%
print(soup.select("body p#i")) # body 자손이면서 id가 i인 p태그들
# Out:
# [<p class="a" id="i">test1</p>]

# %%
print(soup.select("div p")) # div 자손인 p태그들
# Out:
# [<p class="a" id="i">test1</p>, <p class="d">test2</p>]

# %% [markdown]
# ## 웹크롤링 허용 문제
#
# - 모든 사이트에는 웹 크롤링 권한에 관해 명시한 페이지가 있음
#     - 사이트 url끝에 robots.txt를 붙여서 확인
#         - 예) https://www.google.com/robots.txt
#         - Disallow : 허용되지 않는 경로
#         - allow : 크롤링을 허용하는 경로

# %%
url = "https://ai-dev.tistory.com/1"
page = urlopen(url)

soup = BeautifulSoup(page, "lxml")

# %%
# 제목수집
soup.select_one(".hgroup > h1").string.strip()
# Out:
# '크롤링의 세계에 오신 것을 환영합니다.'

# %%
# hello world 수집
soup.select_one("#article-view p").string
# Out:
# 'Hello, world!'

# %% [markdown]
# ## 예제 1-2. 티스토리 크롤링

# %%
url = "https://ai-dev.tistory.com/2"
page = urlopen(url)

soup = BeautifulSoup(page, "lxml")

td = soup.select("tbody td")

for text in td:
    print(text.string)
# Out:
# 상품
# 색상
# 가격
# 셔츠1
# 빨강
# 20000
# 셔츠2
# 파랑
# 19000
# 셔츠3
# 초록
# 18000
# 바지1
# 검정
# 50000
# 바지2
# 파랑
# 51000

# %%
list = soup.select("ul[data-ke-list-type='disc'] > li")
for i in list:
    print(i.string)
[i.string for i in list]
# Out:
# 모니터
# CPU
# 메모리
# 그래픽카드
# 하드디스크
# 키보드
# 마우스
# ['모니터', 'CPU', '메모리', '그래픽카드', '하드디스크', '키보드', '마우스']

# %%
list = soup.select("div.tt_article_useless_p_margin ul li")
for i in list:
    print(i.string)
# Out:
# 모니터
# CPU
# 메모리
# 그래픽카드
# 하드디스크
# 키보드
# 마우스

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
url = "https://music.bugs.co.kr/chart"
page = urlopen(url)

soup = BeautifulSoup(page, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- bgsweb-www908 -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="노래추천, 음악추천, 플레이리스트, essential, 에센셜, 스트리밍, 스밍, 뮤직PD, 노래듣기, 음악다운로드, 페이코" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script type="text/javascript">
# 	if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0
#         || location.href.indexOf("help.bugs.co.kr") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# 	//var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlJs = "/js";
# 	var g_urlMe = "https://music.bugs.co.kr/user";
# 	var g_urlThumbnail = "http://nboardr.bugs.co.kr/thumbnail";
# 	var g_urlOpenalbum = "https://music.bugs.co.kr/openalbum";
# 	var g_urlClipimg = "//image.bugsm.co.kr";
# 	//var g_urlLikes = "https://music.bugs.co.kr/like";
# 	//var g_urlPlaylists = "https://music.bugs.co.kr/playlist";
# 	var g_urlLikes = "https://music.bugs.co.kr/like";
# 	var g_urlPlaylists = "https://music.bugs.co.kr/playlist"
# 	var g_urlListen = "https://music.bugs.co.kr/listen";
# 	var g_urlMyinfo = "https://music.bugs.co.kr/myinfo";
# 	var g_urlSecureMyinfo = "https://secure.bugs.co.kr/myinfo";
# 	var g_urlSearch = "https://music.bugs.co.kr/search";
# 	var g_urlChart = "https://music.bugs.co.kr/chart";
# 	var g_urlPay = "https://music.bugs.co.kr/pay";
# 	var g_urlBilling = "https://pay.bugs.co.kr";
# 	var g_urlPartner = "https://www.bugs.co.kr/Partner";
# 	var g_urlSecurePay = "https://secure.bugs.co.kr/pay";
# 	var g_urlOtu = "https://notu.bugs.co.kr";
# 	var g_urlBoard = "http://board.bugs.co.kr/notice";
# 	var g_urlEvent = "https://music.bugs.co.kr/event";
# 	var g_storageServerRead = "http://nboardr.bugs.co.kr";
# 	var g_storageServerWrite = "https://nboardw.bugs.co.kr";
#     var g_storageServerFileUploadTmp = g_storageServerWrite+"/adminimg/storage/upload";
# 	var g_urlPanel = "https://music.bugs.co.kr/panel";
# 	var g_urlAjax = "https://music.bugs.co.kr";
# 	var g_urlAppsvr = "https://music.bugs.co.kr";
# 	var g_urlMusicPd = "https://music.bugs.co.kr/musicpd";
# 	var g_urlGenre = "https://music.bugs.co.kr/genre";
# 	var g_urlMLounge = "https://mlounge.bugs.co.kr";
# 	var g_urlNinanoclub = "http://ninanoclub.bugs.co.kr";
# 	var g_urlM = "https://m.bugs.co.kr";
# 	var g_urlDl = "https://dl.bugs.co.kr";
# 	var g_urlBGT = "https://bgt.bugs.co.kr";
#
# 	var g_env = "svc";
#
# 	var g_isLogged = false;
# 	var g_msrl = false;
# </script>
# <!-- cache.filePacking : true -->
# <!-- bugs file packing [ open_lib_js ] cached data / start -->
# <script src="//music.bugs.co.kr/filepacking/open_lib_js?env=svc&amp;_t_s_=20240122-0920" type="text/javascript"></script>
# <!-- bugs file packing [ open_lib_js ] cached data / end -->
# <!-- bugs file packing [ bugs_desktopLib_js ] cached data / start -->
# <script src="//music.bugs.co.kr/filepacking/bugs_desktopLib_js?env=svc&amp;_t_s_=20240122-0920" type="text/javascript"></script>
# <!-- bugs file packing [ bugs_desktopLib_js ] cached data / end -->
# <!-- bugs file packing [ bugs_newLib_js ] cached data / start -->
# <script src="//music.bugs.co.kr/filepacking/bugs_newLib_js?env=svc&amp;_t_s_=20240122-0920" type="text/javascript"></script>
# <!-- bugs file packing [ bugs_newLib_js ] cached data / end -->
# <!-- clova issue로 분기 -->
# <script src="/js/swfobject/swfobject.js" type="text/javascript"></script>
# <!-- java enum to js -->
# <script src="https://music.bugs.co.kr/js/enumtojs" type="text/javascript"></script>
# <script src="/js/utils/personMedia.js?version=20220420" type="text/javascript"></script>
# <script src="/js/me/playlist.js?version=20151102" type="text/javascript"></script>
# <script src="/js/log/makePCookie.js" type="text/javascript"></script>
# <script src="/js/player/min/mvHtml5Player.min.js?version=20240122:0920" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/js/utils/fileUploader.js"></script> -->
# <script src="/js/lib/kakao.min.js" type="text/javascript"></script> <!-- <script type="text/javascript" src="/js/lib/kakao.story.min.js"></script> -->
# <!--[if gt IE 7]>
# 	<script type="text/javascript" src="/js/jquery/jquery.ba-hashchange.min.js"></script>
# <![endif]-->
# <!--[if lt IE 9]>
# 	<script type="text/javascript" src="/js/html5/html5shiv.min.js"></script>
# 	<script type="text/javascript" src="/js/json2.js"></script>
# <![endif]-->
# <!-- bugs file packing [ bugs_commonStyle_css ] cached data / start -->
# <link href="//music.bugs.co.kr/filepacking/bugs_commonStyle_css?env=svc&amp;_t_s_=20240122-0920" rel="stylesheet" type="text/css"/>
# <!-- bugs file packing [ bugs_commonStyle_css ] cached data / end -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://music.bugs.co.kr/chart/track/realtime/total" name="twitter:url"/>
# <meta content="벅스!에서 다양한 음악컨텐츠를 볼 수 있습니다." name="twitter:description"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" name="twitter:image:src"/>
# <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:iphone"/>
# <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:ipad"/>
# <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:googleplay"/>
# <meta content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" name="description"/>
# <!-- open graph -->
# <meta content="122936701116206" property="fb:app_id"/>
# <meta content="나를 위한 플리, 벅스" property="og:title"/>
# <meta content="https://music.bugs.co.kr/chart" property="og:url"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" property="og:image"/>
# <meta content="벅스!" property="og:site_name"/>
# <meta content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <!-- twitter card -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:url"/>
# <meta content="@Bugs_play" name="twitter:site"/>
# <meta content="나를 위한 플리, 벅스" name="twitter:title"/>
# <meta content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" name="twitter:description"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" name="twitter:image"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" name="twitter:image:src"/>
# <meta content="벅스" name="twitter:app:name:iphone"/>
# <meta content="벅스" name="twitter:app:name:ipad"/>
# <meta content="벅스" name="twitter:app:name:googleplay"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:app:url:iphone"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:app:url:ipad"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:app:url:googleplay"/>
# <meta content="348555322" name="twitter:app:id:iphone"/>
# <meta content="420598915" name="twitter:app:id:ipad"/>
# <meta content="com.neowiz.android.bugs" name="twitter:app:id:googleplay"/>
# <link href="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" rel="image_src"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" itemprop="image"/>
# <!-- bugs.sns 용 공유 파라미터 -->
# <script>
# 			var bugsSnsParam = {
# 		 			url : "https://music.bugs.co.kr/chart",
# 		 			text : "나를 위한 플리, 벅스",
# 		 			img : "https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png",
# 		 			hashTag : "#벅스",
# 		 			corner : "벅스"
# 		 		}
# 		</script>
# <script>
#       		 var bugsSnsParam2 = {
#                         url : "https://music.bugs.co.kr/chart",
#                         text : "#2018_우리가_사랑한_음악",
#                         img : "https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png",
#                         hashTag : "#벅스",
#                         corner : "벅스"
#                     }
# 		</script>
# <meta content="ko_KR" property="og:locale"/>
# <title>벅스차트 &gt; 곡 차트 &gt; 실시간 &gt; 전체 장르 - 벅스</title>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <!-- 네이버 검색용 메타 -->
# <meta content="0582453e44d4365f5e597d1580911be7a3173ef7" name="naver-site-verification"/>
# <!-- bugs file packing [ bugs_wbugsAll_css ] cached data / start -->
# <link href="//music.bugs.co.kr/filepacking/bugs_wbugsAll_css?env=svc&amp;_t_s_=20240122-0920" rel="stylesheet" type="text/css"/>
# <!-- bugs file packing [ bugs_wbugsAll_css ] cached data / end -->
# <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="icon" type="image/x-icon"/>
# <script src="/js/log/ace_counter.js"></script>
# <script>
# 	$(document).ready(function(){
# 		$("[dotdotdot=Y]").dotdotdot({
# 			watch : "window"
# 		});
# 	});
# 	</script>
# <meta content="" name="last-process-time"/>
# </head><body><span itemscope="" itemtype="http://schema.org/Organization">
# <link href="https://music.bugs.co.kr" itemprop="url"/>
# <a href="https://www.facebook.com/bugsplay" itemprop="sameAs"></a>
# <a href="http://blog.bugs.co.kr" itemprop="sameAs"></a>
# <a href="https://twitter.com/bugs_play" itemprop="sameAs"></a>
# <a href="https://itunes.apple.com/kr/app/bugs/id348555322?mt=8" itemprop="sameAs"></a>
# <a href="https://play.google.com/store/apps/details?id=com.neowiz.android.bugs" itemprop="sameAs"></a>
# </span>
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   try {
#     ga('create', 'UA-97174709-1', 'auto', 'billingTracker');
#   } catch (e) {
#     console.log('GoogleAnalytics Create Error');
#   }
#
#     var sendGoogleAnalyticsEventForBilling = function (category, action, label) {
#       try {
#         ga('billingTracker.send', 'event', category, action, label);
#       } catch (e) {
#         console.log('GoogleAnalytics Send Event Error');
#       }
#     }
#
# </script>
# <div id="skipNav">
# <a href="#container" onclick="$('#container').attr('tabIndex','-1');$('#container').focus();$('body,html').scrollTop(0);return false;"><span>본문 바로가기</span></a>
# <a href="#gnb" onclick="bugs.navigator.setLeftMenuShow(true,true);$('#gnb').attr('tabIndex','-1');$('#gnb').focus();return false;"><span>메뉴 바로가기</span></a>
# <a href="#loginHeader" onclick="$('#loginHeader a:first-of-type').attr('tabIndex','-1');$('#loginHeader a:first-of-type').focus();return false;"><span>로그인 바로가기</span></a>
# <a href="#footer" onclick="$('#footer').attr('tabIndex','-1');$('#footer').focus();return false;"><span>하단 정보 바로가기</span></a>
# </div>
# <div id="wrap">
# <script>
# 	$(document).ready(function(){
# 					if('' == ""){
# 				bugs.searchBoxAd.init();
# 				bugs.searchBoxAd.checkInput();
# 				bugs.searchBoxAd.inputBlur();
# 				bugs.searchBoxAd.deleteText();
# 			}
#
# 		popWebPlayerNotification();
#
# 		bugs.suggest.close();
# 		var headerCommonBanner = '[{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/36142\",\"view_target\":\"ALL\",\"title\":\"겨울 신나는 가요\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":112436,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/436/112/0/112436.jpg\",\"view_start_date\":{\"date\":15,\"hours\":15,\"seconds\":0,\"month\":10,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1700028000000,\"day\":3},\"expire_day\":0,\"regdate\":{\"date\":15,\"hours\":14,\"seconds\":8,\"month\":10,\"timezoneOffset\":-540,\"year\":123,\"minutes\":38,\"time\":1700026688000,\"day\":3},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":27,\"hours\":18,\"seconds\":20,\"month\":11,\"timezoneOffset\":-540,\"year\":123,\"minutes\":20,\"time\":1703668820000,\"day\":3},\"view_end_date\":{\"date\":29,\"hours\":17,\"seconds\":0,\"month\":1,\"timezoneOffset\":-540,\"year\":124,\"minutes\":0,\"time\":1709193600000,\"day\":4},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/85\",\"view_target\":\"ALL\",\"title\":\"겨울 감성 발라드\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":112434,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/434/112/0/112434.jpg\",\"view_start_date\":{\"date\":15,\"hours\":15,\"seconds\":0,\"month\":10,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1700028000000,\"day\":3},\"expire_day\":0,\"regdate\":{\"date\":15,\"hours\":14,\"seconds\":57,\"month\":10,\"timezoneOffset\":-540,\"year\":123,\"minutes\":36,\"time\":1700026617000,\"day\":3},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":27,\"hours\":18,\"seconds\":29,\"month\":11,\"timezoneOffset\":-540,\"year\":123,\"minutes\":20,\"time\":1703668829000,\"day\":3},\"view_end_date\":{\"date\":29,\"hours\":17,\"seconds\":0,\"month\":1,\"timezoneOffset\":-540,\"year\":124,\"minutes\":0,\"time\":1709193600000,\"day\":4},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/32685\",\"view_target\":\"ALL\",\"title\":\"겨울 노래\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":112431,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/431/112/0/112431.jpg\",\"view_start_date\":{\"date\":15,\"hours\":15,\"seconds\":0,\"month\":10,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1700028000000,\"day\":3},\"expire_day\":0,\"regdate\":{\"date\":15,\"hours\":14,\"seconds\":17,\"month\":10,\"timezoneOffset\":-540,\"year\":123,\"minutes\":35,\"time\":1700026517000,\"day\":3},\"totalWeight\":0,\"app_n ...
#
# 		if(headerCommonBanner != ""){
# 			window._headerCommonBannerMainList = bugs.utils.parseJson(headerCommonBanner.split("||")[0]);
# 			window._headerCommonBannerSubList = bugs.utils.parseJson(headerCommonBanner.split("||")[1]);
# 		}
#
# 		headerCommonBannerLoad(location.href);
#
# 		if(bugs.cookie.get("hasCouponEmailID") == "1"){
# 			$("#no_coupon_text").append('<a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D26048%26categoryNo%3D4600" class="linkFAQ" target="_blank">구매한 이용권이 보이지 않는다면?</a>');
# 		}
# 	});
#
# 	function popWebPlayerNotification() {
# 		var flag = Cookies.get("wpn");
# 		if(!flag)
# 			$(".slogan .tip").show();
# 		else
# 			$(".slogan .tip").hide();
# 	};
#
# 	function closeWebPlayerNotification() {
# 		Cookies.set("wpn", "Y", {expires:365*50, path:"/", domain:document.domain});
# 		$(".slogan .tip").hide();
# 	}
#
# 	function headerCommonBannerLoad(url){
# // 		url = window.location.href; //테스트용
#
# 		if(url.indexOf("?") > 0){
# 			url = url.substring(0,url.indexOf("?"))
# 		}
#
# 		if(url == g_urlWww || url == g_urlWww+"/" || url == g_urlWww+"/index" || url == g_urlMusic){ //main
# 			if(typeof window._headerCommonBannerSubList != "undefined" && window._headerCommonBannerMainList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerMainList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+ bugs.common_util.setLinkUrlWiseLog(selectedBanner.link, "M_header_03_03") +'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
#
# 		}else{ //sub
# 			if(typeof window._headerCommonBannerSubList != "undefined" && window._headerCommonBannerSubList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerSubList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+selectedBanner.link+'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
# 		}
#
# 	};
#
# </script>
# <header id="header">
# <aside class="layer layerSettingPlayer guide title" style="display:none;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1>안내</h1>
# </header>
# <section class="layerContents">
# <p class="message">
# 			음악을 재생할 플레이어를 선택해 주세요. <br/>
# 			벅스 웹상단 &gt; <strong>플레이어 선택</strong>에서 플레이어를 변경할 수 있습니다.
# 		</p>
# <fieldset>
# <div class="radioChk"><input checked="checked" id="radio_player_web2" name="radio_player_type2" type="radio" value="WEB"/> <label for="radio_player_web2">웹 플레이어</label></div>
# <div class="radioChk"><input id="radio_player_mac2" name="radio_player_type2" type="radio" value="MAC"/> <label for="radio_player_mac2">벅스 플레이어 (프로그램 설치 필요)</label>
# <p>
# 					v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.<br/>
# <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">[설치 안내 바로가기]</a>
# </p>
# </div>
# </fieldset>
# <p class="agreeCheck">
# <input id="setPlayerSelectionConfirm" name="setPlayer" type="checkbox"/> <label for="setPlayerSelectionConfirm">항상 선택한 플레이어로 재생</label>
# </p>
# <p class="btns">
# <button class="btnNormal" type="ok">확인</button>
# </p>
# </section>
# <button class="btnClose" type="cancel">닫기</button>
# </aside>
# <!-- //플레이어 선택 설정 안내 -->
# <aside class="layer layerSettingPlayer selectPlayer title" style="display:none;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1>플레이어 선택</h1>
# </header>
# <section class="layerContents">
# <p class="message">음악을 재생할 플레이어를 선택해 주세요.</p>
# <fieldset>
# <div class="radioChk">
# <input checked="checked" id="radio_player_web1" name="radio_player_type1" type="radio" value="WEB"/> <label for="radio_player_web1">웹 플레이어</label>
# </div>
# <div class="radioChk">
# <input id="radio_player_mac1" name="radio_player_type1" type="radio" value="MAC"/> <label for="radio_player_mac1">벅스 플레이어 (프로그램 설치 필요)</label>
# <p>
# 					v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.<br/>
# <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">[설치 안내 바로가기]</a>
# </p>
# </div>
# </fieldset>
# <p class="btns">
# <button class="btnNormal" type="ok">확인</button>
# </p>
# </section>
# <button class="btnClose" type="cancel">닫기</button>
# </aside>
# <!-- //플레이어 선택 안내 -->
# <!--
# <aside class="layer layerPlayingPlayer" style="display:none;">
# 	<div class="box-shadow"></div>
#
# 	<section class="layerContents">
# 		<strong class="message">벅스 플레이어로 재생됩니다.</strong>
# 		<ul>
# 			<li>벅스 웹상단 &gt; 플레이어 선택에서 플레이어를 변경할 수 있습니다.</li>
# 			<li>혹시 벅스 플레이어가 실행되지 않는다면? <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" onclick="$('.layerPlayingPlayer').hide();" target="_blank">[설치 안내 바로가기]</a></li>
# 		</ul>
# 	</section>
# </aside>
# -->
# <script type="text/javascript">
# //	var ua = navigator.userAgent;
# //	window._isMacBrowser = navigator.userAgent.search("Mac") > -1;
# //	window._isMacPlayerLinked = /Mac OS X 11_/.test(ua)
# //				|| /Mac OS X 12_/.test(ua)
# //				|| (/Mac OS X 10_/.test(ua) && !/Mac OS X 10_10/.test(ua) && !/Mac OS X 10_9/.test(ua) && !/Mac OS X 10_8/.test(ua) && !/Mac OS X 10_7/.test(ua) && !/Mac OS X 10_6/.test(ua) && !/Mac OS X 10_5/.test(ua)
# //														&& !/Mac OS X 10_4/.test(ua) && !/Mac OS X 10_3/.test(ua) && !/Mac OS X 10_2/.test(ua));
#
# 	var goServiceGuidePlayerPage = function(){
# 		if(navigator.platform.indexOf('Win') > -1){
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer";
# 		}else{
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer";
# 		}
# 	}
#
# 	$(document).ready(function() {
# 		showMacPlayerSelection();
#
# 	});
#
# 	var showMacPlayerSelection = function() {
# 		if(bugs.music.isMacPlayerSupport()) {
# 			$(".slogan .selectPlayer").show();
# 			$(".slogan .goGuideBugsPlayer").hide();
#
# 			var dp = bugs.cookie.get('defaultPlayer') || "";
# 			updateHeaderPlayerMenu(dp);
# 		} else {
# 			$(".slogan .selectPlayer").hide();
# 			$(".slogan .goGuideBugsPlayer").show();
# 		}
# 	}
#
# 	var updateHeaderPlayerMenu = function(type) {
# 		$("#headerWebPlayer").hide();
# 		$("#headerMacPlayer").hide();
#
# 		if(type == "MAC") {
# 			$("#headerMacPlayer").show();
# 		} else { // if(type == "" || type == "WEB") {
# 			$("#headerWebPlayer").show();
# 			$("#headerWebPlayer").removeAttr("onclick");
# 			$("#headerWebPlayer").unbind("click").bind("click", function() {
# 				bugs.music.popWebPlayer();
# 				bugs.wiselog.area('M_header_02_20');
# 				return false;
# 			});
# 		}
# 	}
# </script>
# <div class="top">
# <div class="slogan">
# <a class="btnPlaylistForMe" href="https://music.bugs.co.kr/musicpd?wl_ref=M_header_02_21">나를 위한 플리</a>
# <a class="btnEssential" href="https://music.bugs.co.kr/promotion/essentialPlayerIntroduce?wl_ref=M_header_02_22" target="_blank">essential;</a>
# <a aria-label="새창" class="openPlayer" href="javascript:;" id="headerWebPlayer" onclick="javascript:bugs.music.popWebPlayer();bugs.wiselog.area('M_header_02_13');return false;">웹 플레이어</a>
# <a class="openPlayer" href="bugs3://app/wakeup" id="headerMacPlayer" onclick="bugs.wiselog.area('M_header_02_18');" style="display:none;">벅스 플레이어</a>
# <span class="goGuideBugsPlayer" style="display:none;">
# <a href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_14');}catch(e){} goServiceGuidePlayerPage();">벅스 플레이어</a>
# </span>
# <a aria-label="새창" class="selectPlayer" href="javascript:;" onclick="bugs.ui.showPlayerSettingLayer();bugs.wiselog.area('M_header_02_19');" style="display:none;">플레이어 선택</a>
# </div>
# <div class="rightGroup">
# <div class="more">
# <a href="http://help.bugs.co.kr" onclick="try{bugs.wiselog.area('M_header_02_06');}catch(e){}">고객센터</a>
# <a class="game" href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_08');}catch(e){}bugs.ui.cp.headerGameMenuToggle();">게임</a>
# <aside class="layer gameMenu">
# <div class="box-shadow"></div>
# <ul class="list-layer-select">
# <li><a href="https://game.bugs.co.kr?wl_ref=sub_gnb&amp;wl_ref=M_header_02_11" onclick="try{bugs.wiselog.area('M_header_02_11');}catch(e){}" target="_blank">피망</a></li>
# </ul>
# </aside>
# </div>
# <div class="family">
# <a class="comico" href="https://www.comico.kr" onclick="try{bugs.wiselog.area('M_header_02_03');}catch(e){}" target="_blank">comico</a>
# <a class="ticketlink" href="http://www.ticketlink.co.kr" onclick="try{bugs.wiselog.area('M_header_02_04');}catch(e){}" target="_blank">티켓링크</a>
# <a class="hangame" href="https://www.hangame.com" onclick="try{bugs.wiselog.area('M_header_02_05');}catch(e){}" target="_blank">HANGAME</a>
# </div>
# </div>
# </div>
# <div class="header">
# <a class="logo seasonal hyrend" href="https://music.bugs.co.kr?wl_ref=M_header_03_01">Bugs!<span class="blind">-홈으로 이동</span></a>
# <div class="innerContainer">
# <input id="_hsi" type="hidden"/>
# <fieldset class="searchForm" id="hederSearchForm">
# <div class="input">
# <input autocomplete="off" id="headerSearchInput" title="검색어 입력" type="text"/><span class="adKeywordDelete" id="keywordClearButton"><span class="blind">검색어 삭제</span></span><button class="btnSearch" id="hederSearchFormButton" onclick="bugs.search.searchFromButton();">검색<span class="blind">-페이지 이동</span></button>
# </div>
# <div id="suggest" style="display:none;">
# <div class="box-shadow"></div>
# </div>
# </fieldset>
# <div class="banner"></div>
# </div>
# <div class="rightSection">
# <div class="member">
# <div class="login" id="loginHeader">
# <!-- <a href="javascript:bugs.ui.showLoginLayerForHeader();" onclick="javascript:bugs.wiselog.area('M_header_03_05');">로그인</a>
# 			<a href="https://secure.bugs.co.kr/member/join/memberMain?wl_ref=M_header_03_06" class="signup"><span class="bar"></span> 회원가입<span class="blind">-페이지 이동</span></a> -->
# <a href="javascript:void(0);" onclick="bugs.wiselog.area('M_header_03_05');bugs.ui.showLoginLayerForHeader({caller:this});">로그인 / 회원가입</a>
# </div>
# <div class="notification" id="memberNotificationArea">
# <button id="btnNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;">알림</button>
# <button class="count" id="aNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;"><span class="blind">새로운</span><span>알림</span>0<span class="blind">개</span></button>
# </div>
# </div>
# </div>
# </div>
# </header><div id="gnb">
# <span class="btnMenuFolding" id="gnbHandleBtn" style="display:none">MENU</span>
# <div id="gnbBody">
# <div class="links">
# <div class="inner">
# <a class="btnNormal lounge" href="https://music.bugs.co.kr/member/vipinfo?wl_ref=M_header_02_12">벅스 VIP 멤버십 안내</a>
# <a class="link ticket" href="https://music.bugs.co.kr/pay/recommend?wl_ref=M_left_01_01">이용권 구매</a>
# <a class="link coupon" href="https://music.bugs.co.kr/pay/offlineCoupon?wl_ref=M_left_01_01">상품권 등록</a>
# </div>
# </div>
# <nav>
# <ul>
# <li class="chart"><a class="hyrend" href="https://music.bugs.co.kr/chart?wl_ref=M_left_02_01" lmid="lm_chart">벅스차트</a></li>
# <li class="news"><a class="hyrend" href="https://music.bugs.co.kr/newest?wl_ref=M_left_02_03" lmid="lm_news">최신 음악</a></li>
# <li class="music4u"><a class="hyrend" href="https://music.bugs.co.kr/music4u?wl_ref=M_left_02_02" lmid="lm_m4u" loginrequired="PAGE">뮤직4U</a></li>
# <li class="genre"><a class="hyrend" href="https://music.bugs.co.kr/genre/home?wl_ref=M_left_02_06" lmid="lm_genre">장르</a></li>
# <li class="special"><a class="hyrend" href="https://music.bugs.co.kr/musicpost?wl_ref=M_left_02_08" lmid="lm_special">뮤직포스트</a></li>
# <li class="theme open" folder="2">
# <strong>테마</strong><span class="bu"></span>
# <ul>
# <li><a class="hyrend" href="https://music.bugs.co.kr/musicpd?wl_ref=M_left_02_04" lmid="lm_esalbum">뮤직PD 앨범</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/recomreview?wl_ref=M_left_02_05" lmid="lm_recomreview">추천앨범 리뷰</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/years?wl_ref=M_left_02_07" lmid="lm_years">연도별</a></li>
# </ul>
# </li>
# <li class="favorite"><a href="https://music.bugs.co.kr/favorite?wl_ref=M_left_02_14" lmid="lm_favorite">Favorite</a></li>
# <li class="connect"><a class="hyrend" href="https://music.bugs.co.kr/connect?wl_ref=M_left_02_13" lmid="lm_connect">커넥트</a></li>
# <li class="radio"><a class="hyrend" href="https://music.bugs.co.kr/radio/radioChannel?wl_ref=M_left_02_10" lmid="lm_radio">라디오</a></li>
# <li class="bugsonTV open" folder="5">
# <strong>벅스TV</strong><span class="bu"></span>
# <ul>
# <li class="specialLive"><a href="https://music.bugs.co.kr/musicpost/list/bugstv?wl_ref=M_left_04_04">스페셜 라이브</a></li>
# </ul>
# </li>
# <li class="mymusic open" folder="3">
# <strong>내 음악</strong><span class="bu"></span>
# <ul>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?wl_ref=M_left_03_05" lmid="lm_recentTrack" loginrequired="PAGE">최근 들은 곡</a> <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('',true);">최근 들은 곡 재생</button></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?sort=LISTEN_COUNT&amp;wl_ref=M_left_03_06" lmid="lm_manytimesTrack" loginrequired="PAGE">가장 많이 들은 곡</a> <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('LISTEN_COUNT',true);">가장 많이 들은 곡 재생</button></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/purchased/track?wl_ref=M_left_03_01" lmid="lm_buymusic" loginrequired="PAGE">구매한 음악</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/like/track?wl_ref=M_left_03_02" lmid="lm_likemusic" loginrequired="PAGE">좋아한 음악</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/myalbum/list?wl_ref=M_left_03_03" lmid="lm_myAlbumManage" loginrequired="PAGE">내앨범</a></li>
# </ul>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <script>
# try{
# 	bugs.navigator.setLeftMenuFolder();
# }
# catch(e){}
# </script>
# <div id="hyrendContentBody">
# <article class="mnWhatshot mnChart pgChartTrack" id="container">
# <header class="sectionPadding pgTitle">
# <div class="innerContainer">
# <h1>벅스차트</h1>
# <script type="text/javascript">
#   var toggleNationLayer = function() {
#     $("aside.selectNation").toggle(250, function(){});
#   }
#
# $(document).ready(function () {
#
#   function changeTitle(){
#     try{
#               if('KR' != 'KR'){
#         var newTitle = '벅스차트 > 곡 차트 > 대한민국 - 벅스';
#         var curTitle = document.title;
#         if(newTitle != curTitle){
#           document.title = newTitle;
#         } else {
#           setTimeout(changeTitle, 500);
#         }
#       }
#     } catch(e){}
#   };
#
#   changeTitle();
#
#   $(document).click(function(ev){
#     if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
#     if ($(ev.target).attr('class') != "selectedNationName"
#         && ($(ev.target).attr('class').indexOf("flag") != 0  )
#         && ($(ev.target).attr('class').indexOf("btnNation") == -1 ) ) {
#           $("aside.selectNation").hide(250);
#       }
#     });
# });
# </script>
# <aside class="layer selectNation">
# <div class="box-shadow"></div>
# <h1>국가선택</h1>
# <ul>
# <li><a class="hyrend selected KR" href="https://music.bugs.co.kr/chart/track/realtime/total?nation=KR" onclick="bugs.wiselog.area('chart_nation_KR');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png"/></span><em class="selectedNationName">대한민국</em></a></li>
# <li><a class="hyrend nl" href="https://music.bugs.co.kr/chart/track/week/total?nation=nl" onclick="bugs.wiselog.area('chart_nation_nl');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/NL.png"/></span><em class="selectedNationName">네덜란드</em></a></li>
# <li><a class="hyrend dk" href="https://music.bugs.co.kr/chart/track/week/total?nation=dk" onclick="bugs.wiselog.area('chart_nation_dk');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/DK.png"/></span><em class="selectedNationName">덴마크</em></a></li>
# <li><a class="hyrend de" href="https://music.bugs.co.kr/chart/track/week/total?nation=de" onclick="bugs.wiselog.area('chart_nation_de');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/DE.png"/></span><em class="selectedNationName">독일</em></a></li>
# <li><a class="hyrend us" href="https://music.bugs.co.kr/chart/track/week/total?nation=us" onclick="bugs.wiselog.area('chart_nation_us');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/US.png"/></span><em class="selectedNationName">미국</em></a></li>
# <li><a class="hyrend be" href="https://music.bugs.co.kr/chart/track/week/total?nation=be" onclick="bugs.wiselog.area('chart_nation_be');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/BE.png"/></span><em class="selectedNationName">벨기에</em></a></li>
# <li><a class="hyrend br" href="https://music.bugs.co.kr/chart/track/week/total?nation=br" onclick="bugs.wiselog.area('chart_nation_br');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/BR.png"/></span><em class="selectedNationName">브라질</em></a></li>
# <li><a class="hyrend se" href="https://music.bugs.co.kr/chart/track/week/total?nation=se" onclick="bugs.wiselog.area('chart_nation_se');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/SE.png"/></span><em class="selectedNationName">스웨덴</em></a></li>
# <li><a class="hyrend es" href="https://music.bugs.co.kr/chart/track/week/total?nation=es" onclick="bugs.wiselog.area('chart_nation_es');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/ES.png"/></span><em class="selectedNationName">스페인</em></a></li>
# <li><a class="hyrend ar" href="https://music.bugs.co.kr/chart/track/week/total?nation=ar" onclick="bugs.wiselog.area('chart_nation_ar');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/AR.png"/></span><em class="selectedNationName">아르헨티나</em></a></li>
# <li><a class="hyrend gb" href="https://music.bugs.co.kr/chart/track/week/total?nation=gb" onclick="bugs.wiselog.area('chart_nation_gb');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/GB.png"/></span><em class="selectedNationName">영국</em></a></li>
# <li><a class="hyrend it" href="https://music.bugs.co.kr/chart/track/week/total?nation=it" onclick="bugs.wiselog.area('chart_nation_it');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/IT.png"/></span><em class="selectedNationName">이탈리아</em></a></li>
# <li><a class="hyrend ca" href="https://music.bugs.co.kr/chart/track/week/total?nation=ca" onclick="bugs.wiselog.area('chart_nation_ca');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/CA.png"/></span><em class="selectedNationName">캐나다</em></a></li>
# <li><a class="hyrend fi" href="https://music.bugs.co.kr/chart/track/week/total?nation=fi" onclick="bugs.wiselog.area('chart_nation_fi');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/FI.png"/></span><em class="selectedNationName">핀란드</em></a></li>
# <li><a class="hyrend fr" href="https://music.bugs.co.kr/chart/track/week/total?nation=fr" onclick="bugs.wiselog.area('chart_nation_fr');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/FR.png"/></span><em class="selectedNationName">프랑스</em></a></li>
# <li><a class="hyrend au" href="https://music.bugs.co.kr/chart/track/week/total?nation=au" onclick="bugs.wiselog.area('chart_nation_au');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/AU.png"/></span><em class="selectedNationName">호주</em></a></li>
# </ul>
# </aside>
# <a class="btnGenre" href="javascript:;" onclick="bugs.wiselog.area('S_gfilter_01');toggleGenreLayer();"><em class="selectedGenreName">전체 장르</em></a>
# <script type="text/javascript">
# 	<!--
# 	var toggleGenreLayer = function() {
# 		$("aside.selectGenre").toggle(250, function(){});
# 		$('aside.coachBside').hide();
# 	}
#
# 	var setSelectedType = function(selectedType) {
# 		if (selectedType == "") selectedType = "total";
# 				$('ul.listGenre > li > a').each(function(index) {$(this).removeClass('selected')});
# 		$('ul.listGenre > li[type='+selectedType+'] > a').addClass('selected');
# 	}
#
# 		jQuery(document).ready(function () {
# 			setSelectedType("total");
#
# 			$(document).click(function(ev){
# 				try{
# 					if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
# 					if ($(ev.target).attr('class') != "selectedGenreName"
# 						&& ($(ev.target).attr('class').indexOf("btnGenre") == -1) ) {
# 						$("aside.selectGenre").hide(250);
# 					}
# 				}catch(e){}
# 			});
# 		});
# 	//-->
# 	</script>
# <!-- 장르선택 레이어 -->
# <aside class="layer selectGenre">
# <div class="box-shadow"></div>
# <h1>장르선택</h1>
# <ul class="category">
# <li>
# <em class="all">전체</em>
# <ul class="listGenre">
# <li type="total"><a class="selected hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total">전체 장르</a></li>
# <li type="kpop"><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/kpop">국내 전체 장르</a></li>
# <li type="pop"><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/pop">해외 전체 장르</a></li>
# </ul>
# </li>
# <li>
# <em class="domestic">국내</em>
# <ul class="listGenre">
# <li type="nb"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nb">발라드</a></li>
# <li type="ndp"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/ndp">댄스/팝</a></li>
# <li type="nfa"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nfa">포크/어쿠스틱</a></li>
# <li type="nid"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nid">아이돌</a></li>
# <li type="nrh"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nrh">랩/힙합</a></li>
# <li type="nrs"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nrs">알앤비/소울</a></li>
# <li type="nkelec"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nkelec">일렉트로닉</a></li>
# <li type="nkrock"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nkrock">락/메탈</a></li>
# <li type="nkjazz"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nkjazz">재즈</a></li>
# <li type="nindie"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nindie">인디</a></li>
# <li type="ntrot"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/ntrot">성인가요</a></li>
# </ul>
# </li>
# <li>
# <em class="overseas">해외</em>
# <ul class="listGenre">
# <li type="nfpop"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfpop">팝</a></li>
# <li type="nfhiphop"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfhiphop">랩/힙합</a></li>
# <li type="nfrnb"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfrnb">알앤비/소울</a></li>
# <li type="nfelec"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfelec">일렉트로닉</a></li>
# <li type="nfrock"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfrock">락</a></li>
# <li type="nfmetal"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfmetal">메탈</a></li>
# <li type="nfjazz"><a class="hyrend" data-category="overseas" href="https://music.bugs.co.kr/chart/track/day/nfjazz">재즈</a></li>
# </ul>
# </li>
# <li>
# <em class="etc">기타</em>
# <ul class="listGenre">
# <li type="nost"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nost">OST</a></li>
# <li type="nclassic"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nclassic">클래식</a></li>
# <li type="nnewage"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nnewage">뉴에이지</a></li>
# <li type="njpop"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/njpop">J-POP</a></li>
# <li type="nwpop"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nwpop">월드뮤직</a></li>
# <li type="nkclassic"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nkclassic">국악</a></li>
# <li type="nccm"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nccm">CCM/종교</a></li>
# <li type="nchildren"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nchildren">어린이</a></li>
# <li type="nprenatal"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/nprenatal">태교</a></li>
# <li type="ncarol"><a class="hyrend" data-category="etc" href="https://music.bugs.co.kr/chart/track/day/ncarol">캐롤</a></li>
# </ul>
# </li>
# </ul>
# </aside>
# </div>
# </header>
# <script>
# $(document).ready(function(){
# 			if(bugs.cookie.get('bside_coach_mark') != "N"){
# 			$('aside.coachConnect').show();
# 		}
# });
#
# function bsideCoachMarkClick(){
# 	var oDate = new Date();
# 	oDate.setDate(oDate.getDate() + 3650); //10 years...
# 	$('aside.coachConnect').hide();
# 	bugs.cookie.set('bside_coach_mark', 'N', oDate, "/");
# }
#
#
# </script>
# <nav class="sectionPadding lnb">
# <div class="innerContainer">
# <ul>
# <li><a class="track hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total">곡</a></li>
# <li><a class="album hyrend" href="https://music.bugs.co.kr/chart/album/day/total">앨범</a></li>
# <li><a class="mPDAlbum hyrend" href="https://music.bugs.co.kr/chart/pdalbum/day/total">뮤직PD 앨범</a></li>
# <li><a class="mv hyrend" href="https://music.bugs.co.kr/chart/mv/day/total">영상</a></li>
# <li>
# <a class="connectTrack hyrend" href="https://music.bugs.co.kr/chart/connect/track/day/total">커넥트 곡</a>
# <aside class="coachConnect" style="display:none;">
# <p>
# 								커넥트<br/>
# 								아티스트가 직접 올린 곡과 영상입니다.
# 								<a class="hyrend" href="https://music.bugs.co.kr/connect">더 알아보기</a>
# </p>
# <button class="btnClose" onclick="bsideCoachMarkClick()">닫기</button>
# </aside>
# </li>
# <li><a class="connectVideo hyrend" href="https://music.bugs.co.kr/chart/connect/mv/day/total">커넥트 영상</a></li>
# </ul>
# </div>
# </nav>
# <section class="sectionPadding">
# <div class="innerContainer">
# <fieldset class="filterChart">
# <legend>검색 필터</legend>
# <div class="leftContents">
# <p class="segmented">
# <a class="first selected hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total">실시간</a>
# <a class="hyrend" href="https://music.bugs.co.kr/chart/track/day/total">일간</a>
# <a class="last hyrend" href="https://music.bugs.co.kr/chart/track/week/total">주간</a>
# </p>
# </div>
# <time datetime="2024.01.22 06:00">
#
# 													2024.01.22
# 						<em>09:00</em>
# <a class="btnSelect" href="javascript:void(0);" id="realtimeSelect" onclick="$('aside.realtime').css('left',$(this).offset().left-365);$('aside.realtime').css('top',$(this).offset().top-85);if($('aside.realtime').css('visibility')=='hidden')$('aside.realtime').css('visibility',''); else $('aside.realtime').css('visibility','hidden');">실시간 시간대 선택</a>
# </time>
# </fieldset>
# <script type="text/javascript">
# <!--
# var __trackListCHARTrealtime = null;
# $(function() {
# __trackListCHARTrealtime = new bugs.music.trackList('realtime', 'CHART',false,0);
# __trackListCHARTrealtime.initCheckBox();
# });
# -->
# </script>
# <div id="CHARTrealtime">
# <div class="listControls floatSubMenu" floataddclass="over" lmprop="width">
# <div class="innerContainer">
# <label class="checkbox">
# <input id="checkCHARTrealtime" name="checkAll" onclick="bugs.wiselog.area('list_tr_01_chart');" title="곡 목록 전체" type="checkbox"/>
# </label>
# <span class="btns">
# <a aria-label="새창" class="btnNormal play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_02_chart');__trackListCHARTrealtime.listen(this,true);
# "><span class="blind">선택된 곡 재생</span>듣기</a>
# <a aria-label="새창" class="btnNormal addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_03_chart');__trackListCHARTrealtime.listen(this,false);
# ">재생목록에 추가</a>
# <a aria-label="새창" class="btnNormal addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_04_chart');__trackListCHARTrealtime.addToMyAlbum(this);
# ">내 앨범에 담기</a>
# <a aria-label="새창" class="btnNormal download" href="javascript:;" onclick=" bugs.wiselog.area('list_tr_05_chart');bugs.ui.showLoginLayer();">다운로드</a>
# </span>
# <span class="btns play">
# <span class="leftBar"></span>
# <a aria-label="새창" class="btnNormal play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_06_chart');__trackListCHARTrealtime.listenAll(this,'ALL', false);
# ">전체 듣기<small>(재생목록 추가)</small></a>
# <a aria-label="새창" class="btnNormal play changePlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_18_chart');__trackListCHARTrealtime.listenAll(this,'ALL', true);
# ">전체 듣기<small>(재생목록 교체)</small></a>
# </span>
# </div>
# </div>
# <table class="list trackList byChart">
# <caption>곡 목록</caption>
# <thead>
# <tr>
# <th class="check" scope="col"></th>
# <th class="ranking" scope="col"><span>순위</span></th>
# <th class="albumArt" scope="col"></th>
# <th class="trackInfo" scope="col"></th>
# <th class="title" scope="col"><span>곡</span></th>
# <th class="artist" scope="col"><span>아티스트</span></th>
# <th class="album" scope="col"><span>앨범</span></th>
# <th class="action play" scope="col"><span>듣기</span></th>
# <th class="action add01" scope="col"><span>재생목록</span></th>
# <th class="action add02" scope="col"><span>내앨범</span></th>
# <th class="action download" scope="col"><span>다운</span></th>
# <th class="action mv" scope="col"><span>영상</span></th>
# <th class="action etc" scope="col"><span>기타</span></th>
# </tr>
# </thead>
# <tbody>
# <tr albumid="4094833" artistid="80384286" multiartist="N" mvid="622351" rowtype="track" trackid="6228128">
# <input name="_isStream" type="hidden" value="6228128"/>
# <input name="_isDown" type="hidden" value="6228128"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Love 119" type="checkbox" value="6228128"/></td>
# <td>
# <div class="ranking">
# <strong>1</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4094833?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="Love 119 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40948/4094833.jpg?version=20240109013241.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6228128?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6228128',true);
# " title="Love 119">Love 119</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80384286?wl_ref=list_tr_10_chart" onclick="
# " title="RIIZE">RIIZE</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4094833?wl_ref=list_tr_11_chart" onclick="
# " title="Love 119">Love 119</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6228128',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6228128');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6228128');
# " track_title="Love 119">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6228128','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6228128, 622351, 'Y', 'Y', 'Y', 'Y', 6228128, 'N','ALL', 'Y', '');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="RIIZE" artist_id="80384286" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6228128','0','4094833','bugs.music.listenRadioFromSeed(\'6228128\',\'track\');','N', 'Y', '_chart');
# " track_title="Love 119">기타 기능</a>
# </td>
# </tr>
# <tr albumid="4093522" artistid="80026437" multiartist="N" mvid="621452" rowtype="track" trackid="6223772">
# ...
# <input name="_isStream" type="hidden" value="33041525"/>
# <input name="_isDown" type="hidden" value="33041525"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Soñar (Breaker)" type="checkbox" value="33041525"/></td>
# <td>
# <div class="ranking">
# <strong>100</strong>
# <p class="change up"><span class="arrow"></span> <em>6</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/20609824?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="Fe3O4: BREAK 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/206098/20609824.jpg?version=20240116010926.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/33041525?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33041525',true);
# " title="Soñar (Breaker)">Soñar (Breaker)</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80365655?wl_ref=list_tr_10_chart" onclick="
# " title="NMIXX">NMIXX</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/20609824?wl_ref=list_tr_11_chart" onclick="
# " title="Fe3O4: BREAK">Fe3O4: BREAK</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33041525',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33041525');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33041525');
# " track_title="Soñar (Breaker)">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33041525','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,33041525, 621647, 'Y', 'Y', 'Y', 'Y', 33041525, 'N','OVER_12', 'Y', '');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="NMIXX" artist_id="80365655" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'33041525','0','20609824','bugs.music.listenRadioFromSeed(\'33041525\',\'track\');','N', 'Y', '_chart');
# " track_title="Soñar (Breaker)">기타 기능</a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="pageAdditionalInfo">
# <ul>
# <li><span class="icon"></span>집계기간 내 듣기와 다운로드 수 합산하여 반영</li>
# </ul>
# </div>
# <script>
# $(document).ready(function(){
# 		var contentsBanner = '[]';
#
# 	if(contentsBanner != "" && contentsBanner != "[]" ){
# 		contentsBanner = bugs.utils.parseJson(contentsBanner);
# 		var wiselogStr = "";
# 		for(var i = 0; i < contentsBanner.length && i < 3; i++){
# 			if(i==0){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_01');"
# 			}else if( i==1){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_02');"
# 			}else if( i==2){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_03');"
# 			}
# 			$('#contentsBanner'+(i+1)).empty();
# 			$('#contentsBanner'+(i+1)).append('<a href="'+contentsBanner[i].link+'" target="'+contentsBanner[i].target+
# 					'" onclick="'+wiselogStr+'bugs.logging.banner('+contentsBanner[i].banner_id+','+"'banner'"+')" title="'+contentsBanner[i].title+'-페이지 이동">'+
# 											'<img src="'+contentsBanner[i].image_path+'" alt="'+contentsBanner[i].title+'"></a>');
# 		}
#
# 		var oldWidth = $(window).width();
# 		if(oldWidth < 1903){
# 			$('#contentsBanner2').addClass('lineBreak');
# 		}else{
# 			$('#contentsBanner3').addClass('lineBreak');
# 		}
# 		var currentWidth = 0;
# 		$(window).on('resize',function(){
# 			currentWidth = $(window).width();
# 			if(oldWidth < 1903 && 1903 <= currentWidth){
# 				$('#contentsBanner2').removeClass('lineBreak');
# 				$('#contentsBanner3').addClass('lineBreak');
# 			}else if(currentWidth < 1903 && 1903 <= oldWidth){
# 				$('#contentsBanner3').removeClass('lineBreak');
# 				$('#contentsBanner2').addClass('lineBreak');
# 			}
# 			oldWidth = currentWidth;
# 		});
#
# 		$('aside.contentsBanner').show();
# 	}
#
# });
# </script>
# <aside class="contentsBanner" style="display:none;">
# <ul class="listContentsBanner">
# <li id="contentsBanner1">
# </li>
# <li id="contentsBanner2">
# </li>
# <li id="contentsBanner3">
# </li>
# </ul>
# </aside>
# </div>
# </section>
# <!-- 레이어 - 실시간  -->
# <aside class="layer layer-select realtime" style="top: 165px;left: 600px;display:block;visibility:hidden;">
# <div class="box-shadow"></div>
# <h1>선택 레이어</h1>
# <div class="innerScroll">
# <ul class="list-layer-select center">
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20240122&amp;charthour=09">09:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20240122&amp;charthour=08">08:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20240122&amp;charthour=07">07:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20240122&amp;charthour=01">01:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20240122&amp;charthour=00">00:00</a></li>
# </ul>
# </div>
# </aside>
# </article>
# </div>
# <div class="floatingTop">
# <a class="btnTop" href="javascript:void(bugs.navigator.scrollTop())">TOP</a>
# </div>
# <script src="/js/jquery/jquery-dateFormat.min.js" type="text/javascript"></script>
# <script>
# $(window.document).ready(function() {
# 			setTimeout(function(){
# 				$.ajax({
# 					url : g_urlAjax + "/board/notice/ajax/commonfooternotice",
# 					type : "POST",
# 					dataType : "json",
# 					success : function(data){
# 						if(data != null){
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").text(data.title);
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").attr("href", g_urlMusic + "/board/notice?srl=" + data.srl + "&wl_ref=M_footer_01_01");
# 							$("#commonFooterNotice time").text(data.str_crt_dt);
# 							$("#commonFooterNotice time").attr("datetime", $.format.date(Date.parse(data.str_crt_dt,"yyyy.MM.dd"), "yyyy-MM-dd"));
# 						}
# 					}
# 				});
# 			}, 1300);
#
# });
# </script>
# <script src="/js/bugs/bugs.footer.layer.js" type="text/javascript"></script>
# <footer id="footer">
# <section class="sectionPadding">
# <div class="innerContainer">
# <div class="notice" id="commonFooterNotice">
# <strong><a href="https://music.bugs.co.kr/board/notice?wl_ref=M_footer_01_01">공지사항</a></strong>
# <a href="javascript:;" id="commonFooterNoticeTitle"></a>
# <time datetime=""></time>
# </div>
# <div class="quicklinks">
# <ul>
# <li><a href="https://music.bugs.co.kr/event?wl_ref=M_footer_02_01">이벤트</a></li>
# <li><a href="https://music.bugs.co.kr/panel?wl_ref=M_footer_02_01">벅스패널</a></li>
# </ul>
# <ul>
# <li><a href="https://music.bugs.co.kr/serviceGuide/home?wl_ref=M_footer_02_07">벅스 꿀팁 보기</a></li>
# </ul>
# </div>
# </div>
# </section>
# <section class="sectionPadding contents">
# <div class="innerContainer">
# <ul class="links">
# <li><a href="http://www.bugscorp.co.kr?wl_ref=M_footer_03_01" target="_blank">회사소개</a></li>
# <li><a href="https://music.bugs.co.kr/cooperation?wl_ref=M_footer_03_01">제휴문의</a></li>
# <li><a href="https://music.bugs.co.kr/rules/use?wl_ref=M_footer_03_01">이용약관</a></li>
# <li><a href="https://music.bugs.co.kr/rules/privacy?wl_ref=M_footer_03_01"><em>개인정보처리방침</em></a></li>
# <li><a href="https://music.bugs.co.kr/rules/youth?wl_ref=M_footer_03_01">청소년보호정책</a></li>
# <li><a href="https://music.bugs.co.kr/connect/center?wl_ref=M_footer_03_01">커넥트 센터</a></li>
# <li><a href="http://help.bugs.co.kr?wl_ref=M_footer_03_01">고객센터</a></li>
# <li><a href="https://music.bugs.co.kr/sitemap?wl_ref=M_footer_03_01">사이트맵</a></li>
# <li><a href="https://inside.nhn.com/br/index.nhn" target="_blank">NHN 브랜드 사이트</a></li>
# </ul>
# <aside>
# <div class="sns">
# <a class="blog" href="https://blog.naver.com/blog_bugs" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">블로그</a>
# <a class="facebook" href="https://www.facebook.com/bugsplay" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">페이스북</a>
# <a class="kakaostory" href="https://story.kakao.com/ch/bugs" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">카카오스토리</a>
# </div>
# <div class="familysite">
# <button onclick="bugs.ui.cp.footerFamilySiteMenu(this);" tabindex="0">FAMILY SITE</button>
# <aside class="layer familysiteMenu">
# <div class="box-shadow"></div>
# <ul class="list-layer-select">
# <li><a href="http://www.nhn.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">NHN</a></li>
# <li><a href="http://me.sayclub.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">세이클럽</a></li>
# </ul>
# </aside>
# </div>
# </aside>
# <address>
# <span>(주)엔에이치엔벅스</span>
# <span>06043 서울특별시 강남구 강남대로 586, 제이빌딩</span>
# <span>대표이사 : 왕문주</span>
# <span>고객센터 : <a href="mailto:help@help.bugs.co.kr">help@help.bugs.co.kr</a> / 1566-4882 (유료)</span><br/>
# <span>사업자등록번호 : 211-87-15555</span>
# <span>통신판매업 신고번호 : 제2023-강남-04353호</span>
# <span>호스팅 제공자 : (주)엔에이치엔벅스</span>
# <span><a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2118715555" target="_blank">사업자 정보 확인</a></span>
# <span>© NHN Bugs Corp. All rights reserved.</span>
# </address>
# <script>
#
# if (!bugs.ui.cp) {
# 	bugs.ui.cp = {
# 		headerGameMenuToggle : function() {
# 			$('.layer.gameMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_header_02_02');
# 			}
# 		},
# 		footerFamilySiteMenu : function() {
# 			$('.layer.familysiteMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_fotter_03_01');
# 			}
# 		}
# 	};
# }
#
# </script>
# <ul class="emblem">
# <li>
# <a href="https://help.bugs.co.kr/hc/notice/2586/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="Google Play 선정 2018 올해를 빛낸 앱" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemGooglePlay.png"/>
# </a>
# </li>
# <li>
# <a href="https://music.bugs.co.kr/specialView/supersound/NJ6P8GAP0ERQFD84GUCF" onclick="bugs.wiselog.area('M_fotter_03_01');">
# <img alt="하이 레졸루션 공식인증" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHiRes.png"/>
# </a>
# </li>
# <li>
# <a href="https://help.bugs.co.kr/hc/notice/1933/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="2015 상반기 대학생선호브랜드 대상" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHerald.png"/>
# </a>
# </li>
# <li>
# <a href="https://help.bugs.co.kr/hc/notice/1522/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="스마트앱어워드 대상 수상" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemAppaward.png"/>
# </a>
# </li>
# <li>
# <button onclick="bugs.footer.layer.showIsms();">
# <img alt="정보보호 관리체계 ISMS 인증" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemISMSV202108.png"/>
# </button>
# </li>
# <li>
# <img alt="음악저작권 이용 허락 인증" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemClms.png"/>
# </li>
# <li>
# <a href="https://www.kcopa.or.kr/lay1/S1T356C360/contents.do" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="저작권안심" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemCopyrightokV20220803.png"/>
# </a>
# </li>
# </ul>
# </div>
# </section>
# </footer>
# </div>
# <!--<a href="javascript:void(playlists.resetPlaylist())">리셋하기</a>-->
# <script type="text/javascript">
# $(document).ready(function(){
# 	try{
# 		bugs.navigator.addHyrendUnloadHandler(function(){playlists.playlistLayerHide();},"track2playlistForMoveHyrend", true);
# 	}catch(e){}
#
# });
# </script>
# <aside class="layer layer-select addMyAlbum" id="track2playlist" style="display:none;">
# <div class="box-shadow"></div>
# <h1>내 앨범 목록</h1>
# <div autoscroll="N" class="innerScroll" id="track2playlistScrollArea">
# <ul class="list-layer-select">
# <li><a href="javascript:;" onclick="$('#track2playlist').hide('blind', {}, 'normal', function() { bugs.ui.modalLayer.hide();playlists.make(); });" title="새 앨범 만들기">+ 새 앨범 만들기</a></li>
# </ul>
# </div>
# </aside>
# <!-- 레이어 - 내 앨범 수정 -->
# <aside class="layer createMyAlbum" id="editMyAlbumLayer" style="display:none; z-index:1002;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1>앨범 정보 수정</h1>
# </header>
# <section class="layerContents">
# <fieldset>
# <legend>내 앨범 수정</legend>
# <table class="formLayout">
# <caption>내 앨범 수정 입력 폼</caption>
# <tbody>
# <tr>
# <th scope="row"><label class="lb" for="editMyAlbumLayerPhoto">사진</label></th>
# <td>
# <img alt="" class="thumb" id="editMyAlbumLayerPhoto_img" src="https://file.bugsm.co.kr/wbugs/common/i_defaultMyAlbum_50x50.png"/>
# <div class="inputFile">
# <input class="file" diabled="" id="editMyAlbumLayerPhoto" type="text"/>
# <button class="btnNormal" id="searchImage" type="button">찾아보기</button>
# <input id="editMyAlbumLayerPhoto_path" title="사진경로" type="hidden"/>
# </div>
# </td>
# <td class="right" style="width:55px;"></td>
# </tr>
# <tr>
# <th scope="row" style="width:55px;"><label class="lb" for="editMyAlbumLayerTitle">제목</label></th>
# <td><input class="txt" id="editMyAlbumLayerTitle" type="text" value="111"/></td>
# <td class="right" style="width:55px;"><span class="remain" id="editMyAlbumLayerTitleRemain">(0/100)</span></td>
# </tr>
# <tr>
# <th scope="row"><label class="lb" for="editMyAlbumLayerDescribe">설명</label></th>
# <td>
# <textarea class="txtArea" cols="30" id="editMyAlbumLayerDescribe" name="" rows="10"></textarea>
# </td>
# <td class="right"><span class="remain" id="editMyAlbumLayerDescribeRemain">(0/300)</span></td>
# </tr>
# </tbody>
# </table>
# <p class="btns">
# <button btntype="ok" class="btnNormal" id="editMyAlbumLayerUpdate">저장</button>
# <button btntype="cancel" class="btnNormal" id="editMyAlbumLayerCancel">취소</button>
# </p>
# </fieldset>
# </section>
# <button btntype="close" class="btnClose" id="editMyAlbumLayerClose">닫기</button>
# </aside>
# <aside class="layer createMyAlbum" id="createMyAlbumLayer" style="display:none; z-index:1000;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1 id="createMyAlbumLayerHeader"></h1>
# </header>
# <section class="layerContents">
# <fieldset>
# <legend id="createMyAlbumLayerLegend"></legend>
# <div class="row">
# <label for="createMyAlbumLayerTitle">제목</label>
# <div class="col">
# <input class="txt" id="createMyAlbumLayerTitle" type="text" value=""/>
# <span class="remain" id="createMyAlbumLayerTitleRemain">(0/100)</span>
# </div>
# </div>
# <div class="btns">
# <button btntype="ok" class="btnNormal strong" id="createMyAlbumLayerUpdate">저장</button>
# <button btntype="cancel" class="btnNormal" id="createMyAlbumLayerCancel">취소</button>
# </div>
# </fieldset>
# </section>
# <button btntype="close" class="btnClose" id="crerateMyAlbumLayerClose">닫기</button>
# </aside>
# <span id="removeSpecialCharTarget" style="display:none;"></span>
# <script>
# try{
# 	bugs.navigator.setLeftMenuShowOnLoad();
# }
# catch(e){}
# $(document).ready(function(){
# 	var isFirefox = navigator.userAgent.toLowerCase().indexOf('firefox') > -1;
# 	if(isFirefox){
# 		$("#skipNav").css({top:"1px", left:"1px"});
# 	}
# });
# </script>
# <!-- 470517  -->
# <script>
# try {
# 		var expTime = (new Date()).getTime() + (60*60*24*30*1000);
# 	var expTime2 = (new Date()).getTime() - (60*5*1000);
# 	    bugs.cookie.set("last_login_log_date_cookie","", expTime2, "/", "bugs.co.kr");
# }
# catch(e){}
# </script>
# <!-- 공통 적용 스크립트 , 모든 페이지에 노출되도록 설치. 단 전환페이지 설정값보다 항상 하단에 위치해야함 -->
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"> </script>
# <script type="text/javascript">
#     if (!wcs_add) var wcs_add={};
#     wcs_add["wa"] = "s_595467f7a42";
#     if (!_nasa) var _nasa={};
#     wcs.inflow("bugs.co.kr");
#     wcs_do(_nasa);
# </script>
# </body></html>

# %%
for data in soup.select("#CHARTrealtime p.title"):
    print(data.text.strip())
# Out:
# Love 119
# To. X
# 비의 랩소디
# Perfect Night
# Drama
# MANIAC
# 에피소드
# Get A Guitar
# DASH
# I AM
# 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# You & Me
# 인사
# 헤어지자 말해요
# Ditto
# 한 페이지가 될 수 있게
# Baddie
# Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush)
# ETA
# Discord
# Hype Boy
# Love Lee
# 첫 눈
# 후라이의 꿈
# Talk Saxy
# Seven (feat. Latto) - Clean Ver.
# 넌 쉽게 말했지만
# Super Shy
# Steal The Show (From “엘리멘탈”)
# 잠시라도 우리
# Standing Next to You
# GODS
# Chill Kill
# 예뻤어
# 숲
# 화이트 (White)
# Spicy
# Off The Record
# 너의 모든 순간
# 사건의 지평선
# 그대가 내 안에 박혔다
# Kitsch
# 별 떨어진다 (I Do)
# 기억해줘요 내 모든 날과 그때를
# 머물러주오 (Prod. 안신애 & Philtre)
# Attention
# After LIKE
# LOVE DIVE
# 한번만 더
# Either Way
# 사랑할 수밖에
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 음악의 신
# 퀸카 (Queencard)
# OMG
# 이브, 프시케 그리고 푸른 수염의 아내
# 꿈
# Try Again
# New Jeans
# 잘 지내자, 우리 (여름날 우리 X 로이킴)
# Fast Forward
# Dangerously
# I Don’t Think That I Like Her
# 그대가 내 안에 박혔다(그내박)
# Underwater
# 파이팅 해야지 (Feat. 이영지)
# I Love You (Prod. 김도훈)
# 모든 날, 모든 순간 (Every day, Every Moment)
# Smoke (Prod. Dynamicduo, Padi)
# 주저하는 연인들을 위해
# I Love You
# DIE 4 YOU
# 손오공
# 건물 사이에 피어난 장미 (Rose Blossom)
# 사랑인가 봐
# 달빛에 그려지는
# 다정히 내 이름을 부르면
# UNFORGIVEN (feat. Nile Rodgers)
# 심(心)
# 사막에서 꽃을 피우듯
# STAY
# Bubble
# 미워 (Ego)
# When I Get Old
# Summer (Feat. BE’O (비오))
# 사랑은 늘 도망가
# 운이 좋았지
# @은영이에게
# Melt Away
# ANTIFRAGILE
# Cool With You
# 입술 (Feat. 10CM)
# 어른
# Off My Face
# 내일 얘기해
# 취중고백
# 그대가 있는 곳, 언제 어디든
# 밤, 바다
# Snowman
# Soñar (Breaker)

# %%
print("제목\t 가수\t 앨범\t")
for data in soup.select(".byChart > tbody"):
    for char in data.select("tr"):
        print("{0:20s} \t {1:20s}\t {2:10s}\t".format(char.select_one("p.title").text.strip(),char.select_one("p.artist").text.strip(),char.select_one("a.album").text.strip()), end = '\n')
# Out:
# 제목	 가수	 앨범
# Love 119             	 RIIZE               	 Love 119
# To. X                	 태연 (TAEYEON)        	 To. X - The 5th Mini Album
# 비의 랩소디               	 임재현                 	 비의 랩소디
# Perfect Night        	 LE SSERAFIM (르세라핌)  	 Perfect Night
# Drama                	 aespa               	 Drama - The 4th Mini Album
# MANIAC               	 VIVIZ (비비지)         	 The 4th Mini Album 'VERSUS'
# 에피소드                 	 이무진                 	 에피소드
# Get A Guitar         	 RIIZE               	 Get A Guitar
# DASH                 	 NMIXX               	 Fe3O4: BREAK
# I AM                 	 IVE (아이브)           	 I've IVE
# 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) 	 너드커넥션(Nerd Connection)	 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# You & Me             	 제니 (JENNIE)         	 JENNIE Special Single [You & Me]
# 인사                   	 범진                  	 인사
# 헤어지자 말해요             	 박재정                 	 1집 Alone
# Ditto                	 NewJeans            	 NewJeans 'OMG'
# 한 페이지가 될 수 있게        	 DAY6 (데이식스)         	 The Book of Us : Gravity
# Baddie               	 IVE (아이브)           	 I'VE MINE
# Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush) 	 그루비룸 (GroovyRoom)   	 Yes or No
# ETA                  	 NewJeans            	 NewJeans 2nd EP 'Get Up'
# Discord              	 QWER                	 1st Single Album 'Harmony from Discord'
# Hype Boy             	 NewJeans            	 NewJeans 1st EP 'New Jeans'
# Love Lee             	 AKMU(악뮤)            	 Love Lee
# 첫 눈                  	 EXO                 	 겨울 스페셜 앨범 '12월의 기적 (Miracles in December)’
# 후라이의 꿈               	 AKMU(악뮤)            	 Love Lee
# Talk Saxy            	 RIIZE               	 Talk Saxy
# Seven (feat. Latto) - Clean Ver. 	 정국                  	 Seven (feat. Latto) - Clean Ver.
# 넌 쉽게 말했지만            	 소수빈                 	 싱어게인3 - 무명가수전 Episode.8
# Super Shy            	 NewJeans            	 NewJeans 2nd EP 'Get Up'
# Steal The Show (From “엘리멘탈”) 	 Lauv(라우브)           	 Steal The Show (From “엘리멘탈”)
# 잠시라도 우리              	 성시경
#
#
# 성시경          	 잠시라도 우리
# Standing Next to You 	 정국                  	 GOLDEN
# GODS                 	 NewJeans
#
#
# NewJeans	 2023 리그 오브 레전드 월드 챔피언십 주제곡
# Chill Kill           	 Red Velvet (레드벨벳)   	 Chill Kill - The 3rd Album
# 예뻤어                  	 DAY6 (데이식스)         	 Every DAY6 February
# 숲                    	 최유리                 	 유영
# 화이트 (White)          	 폴킴(Paul Kim)        	 화이트 (White)
# Spicy                	 aespa               	 MY WORLD - The 3rd Mini Album
# Off The Record       	 IVE (아이브)           	 I'VE MINE
# 너의 모든 순간             	 성시경                 	 별에서 온 그대 (SBS 수목드라마) OST - Part.7
# 사건의 지평선              	 윤하(Younha/ユンナ)      	 YOUNHA 6th Album Repackage 'END THEORY : Final Edition'
# 그대가 내 안에 박혔다         	 황치열                 	 그대가 내 안에 박혔다
# Kitsch               	 IVE (아이브)           	 I've IVE
# 별 떨어진다 (I Do)        	 디오 (D.O.)           	 기대 - The 2nd Mini Album
# 기억해줘요 내 모든 날과 그때를    	 화곡동 청개구리            	 기억해줘요 내 모든 날과 그때를
# 머물러주오 (Prod. 안신애 & Philtre) 	 소수빈                 	 싱어게인3 - 무명가수전 Episode.12
# Attention            	 NewJeans            	 NewJeans 1st EP 'New Jeans'
# After LIKE           	 IVE (아이브)           	 After LIKE
# LOVE DIVE            	 IVE (아이브)           	 LOVE DIVE
# 한번만 더                	 소수빈                 	 싱어게인3 - 무명가수전 Episode.13
# Either Way           	 IVE (아이브)           	 I'VE MINE
# 사랑할 수밖에              	 볼빨간사춘기              	 Merry Go Round
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 	 AKMU(악뮤)            	 항해
# 음악의 신                	 세븐틴(SEVENTEEN)      	 SEVENTEEN 11th Mini Album ‘SEVENTEENTH HEAVEN'
# 퀸카 (Queencard)       	 (여자)아이들             	 I feel
# OMG                  	 NewJeans            	 NewJeans 'OMG'
# 이브, 프시케 그리고 푸른 수염의 아내 	 LE SSERAFIM (르세라핌)  	 UNFORGIVEN
# 꿈                    	 태연 (TAEYEON)        	 웰컴투 삼달리 OST Part.3
# Try Again            	 소수빈                 	 싱어게인3 - 무명가수전 Episode.11
# New Jeans            	 NewJeans            	 NewJeans 2nd EP 'Get Up'
# 잘 지내자, 우리 (여름날 우리 X 로이킴) 	 로이킴                 	 잘 지내자, 우리 (여름날 우리 X 로이킴)
# Fast Forward         	 전소미                 	 GAME PLAN
# Dangerously          	 Charlie Puth(찰리 푸스) 	 Nine Track Mind (Deluxe Edition)
# I Don’t Think That I Like Her 	 Charlie Puth(찰리 푸스) 	 I Don’t Think That I Like Her
# 그대가 내 안에 박혔다(그내박)    	 순순희(기태)             	 그대가 내 안에 박혔다(그내박)
# Underwater           	 권은비                 	 Lethality
# 파이팅 해야지 (Feat. 이영지)  	 부석순(SEVENTEEN)      	 부석순 1st Single Album 'SECOND WIND'
# I Love You (Prod. 김도훈) 	 홍이삭                 	 싱어게인3 - 무명가수전 Episode.12
# 모든 날, 모든 순간 (Every day, Every Moment) 	 폴킴(Paul Kim)        	 '키스 먼저 할까요?' OST Part.3
# Smoke (Prod. Dynamicduo, Padi) 	 다이나믹 듀오
#
#
# 다이나믹 듀오  	 스트릿 우먼 파이터2(SWF2) 계급미션
# 주저하는 연인들을 위해         	 잔나비                 	 전설
# I Love You           	 안세하                 	 I Love You
# DIE 4 YOU            	 DEAN(딘)             	 4:44
# 손오공                  	 세븐틴(SEVENTEEN)      	 SEVENTEEN 10th Mini Album ‘FML'
# 건물 사이에 피어난 장미 (Rose Blossom) 	 H1-KEY (하이키)        	 H1-KEY 1st Mini Album [Rose Blossom]
# 사랑인가 봐               	 멜로망스(MeloMance)     	 사랑인가 봐 (사내맞선 OST 스페셜 트랙)
# 달빛에 그려지는             	 미연 ((여자)아이들)        	 연인 OST Part.4
# 다정히 내 이름을 부르면        	 경서예지
#
#
# 경서예지        	 다정히 내 이름을 부르면 (경서예지 x 전건호)
# UNFORGIVEN (feat. Nile Rodgers) 	 LE SSERAFIM (르세라핌)  	 UNFORGIVEN
# 심(心)                 	 DK(디셈버)             	 심(心)
# 사막에서 꽃을 피우듯          	 우디(Woody)           	 사막에서 꽃을 피우듯
# STAY                 	 The Kid LAROI
#
#
# The Kid LAROI	 STAY
# Bubble               	 STAYC(스테이씨)         	 TEENFRESH
# 미워 (Ego)             	 Crush               	 wonderego
# When I Get Old       	 Christopher(크리스토퍼)
#
#
# Christopher(크리스토퍼)	 When I Get Old
# Summer (Feat. BE’O (비오)) 	 Paul Blanco         	 Summer
# 사랑은 늘 도망가            	 임영웅                 	 신사와 아가씨 OST Part.2
# 운이 좋았지               	 권진아                 	 나의 모양
# @은영이에게               	 #안녕                 	 @은영이에게
# Melt Away            	 태연 (TAEYEON)        	 To. X - The 5th Mini Album
# ANTIFRAGILE          	 LE SSERAFIM (르세라핌)  	 ANTIFRAGILE
# Cool With You        	 NewJeans            	 NewJeans 2nd EP 'Get Up'
# 입술 (Feat. 10CM)      	 헤이즈(Heize)          	 Last Winter
# 어른                   	 Sondia              	 나의 아저씨 (tvN 수목드라마) OST - Part.2
# Off My Face          	 Justin Bieber(저스틴 비버)	 Justice
# 내일 얘기해               	 릴러말즈 (Leellamarz)
#
#
# 릴러말즈 (Leellamarz)	 [B]
# 취중고백                 	 김민석                 	 취중고백
# 그대가 있는 곳, 언제 어디든     	 로이킴                 	 로이킴 X 마이데몬
# 밤, 바다                	 최유리                 	 여행: 플리(playlist) OST Part.2
# Snowman              	 Sia(시아)             	 Everyday Is Christmas (Snowman Deluxe Edition)
# Soñar (Breaker)      	 NMIXX               	 Fe3O4: BREAK
